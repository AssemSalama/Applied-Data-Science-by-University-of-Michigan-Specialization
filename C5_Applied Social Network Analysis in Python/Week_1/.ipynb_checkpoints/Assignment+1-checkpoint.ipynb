# %% [markdown]
# ---
#
# _You are currently looking at **version 1.1** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-social-network-analysis/resources/yPcBs) course resource._
#
# ---

# %% [markdown]
# # Don't run this ASS locally ya Asoma.

# %% [markdown]
# # Assignment 1 - Creating and Manipulating Graphs
#
# Eight employees at a small company were asked to choose 3 movies that they would most enjoy watching for the upcoming company movie night. These choices are stored in the file `Employee_Movie_Choices.txt`.
#
# A second file, `Employee_Relationships.txt`, has data on the relationships between different coworkers.
#
# The relationship score has value of `-100` (Enemies) to `+100` (Best Friends). A value of zero means the two employees haven't interacted or are indifferent.
#
# Both files are tab delimited.

# %%
import networkx as nx
import pandas as pd
import numpy as np
from networkx.algorithms import bipartite


# This is the set of employees
employees = set(['Pablo',
                 'Lee',
                 'Georgia',
                 'Vincent',
                 'Andy',
                 'Frida',
                 'Joan',
                 'Claude'])

# This is the set of movies
movies = set(['The Shawshank Redemption',
              'Forrest Gump',
              'The Matrix',
              'Anaconda',
              'The Social Network',
              'The Godfather',
              'Monty Python and the Holy Grail',
              'Snakes on a Plane',
              'Kung Fu Panda',
              'The Dark Knight',
              'Mean Girls'])


# you can use the following function to plot graphs
# make sure to comment it out before submitting to the autograder
def plot_graph(G, weight_name=None):
    '''
    G: a networkx G
    weight_name: name of the attribute for plotting edge weights (if G is weighted)
    '''
    # %matplotlib notebook
    import matplotlib.pyplot as plt
    
    plt.figure()
    pos = nx.spring_layout(G)
    edges = G.edges()
    weights = None
    
    if weight_name:
        weights = [int(G[u][v][weight_name]) for u,v in edges]
        labels = nx.get_edge_attributes(G,weight_name)
        nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
        nx.draw_networkx(G, pos, edges=edges, width=weights);
    else:
        nx.draw_networkx(G, pos, edges=edges);

# %% [markdown]
# ### Question 1
#
# Using NetworkX, load in the bipartite graph from `Employee_Movie_Choices.txt` and return that graph.
#
# *This function should return a networkx graph with 19 nodes and 24 edges*

# %%
# !cat Employee_Movie_Choices.txt
# Out:
# #Employee	Movie
# Andy	Anaconda
# Andy	Mean Girls
# Andy	The Matrix
# Claude	Anaconda
# Claude	Monty Python and the Holy Grail
# Claude	Snakes on a Plane
# Frida	The Matrix
# Frida	The Shawshank Redemption
# Frida	The Social Network
# Georgia	Anaconda
# Georgia	Monty Python and the Holy Grail
# Georgia	Snakes on a Plane
# Joan	Forrest Gump
# Joan	Kung Fu Panda
# Joan	Mean Girls
# Lee	Forrest Gump
# Lee	Kung Fu Panda
# Lee	Mean Girls
# Pablo	The Dark Knight
# Pablo	The Matrix
# Pablo	The Shawshank Redemption
# Vincent	The Godfather
# Vincent	The Shawshank Redemption
# Vincent	The Social Network

# %%
B_net = nx.read_edgelist('Employee_Movie_Choices.txt',delimiter='\t')
B_net

# %%
# make sure it's bipartite
bipartite.is_bipartite(B_net)
# Out:
# True

# %%
print('num of edges =' ,len(B_net.edges(data=True)))
print( 'num of nodes =' ,len(B_net.nodes()))

B_net.edges()[:10]
# Out:
# num of edges = 24
# num of nodes = 19
# [('Andy', 'Anaconda'),
#  ('Andy', 'Mean Girls'),
#  ('Andy', 'The Matrix'),
#  ('Anaconda', 'Claude'),
#  ('Anaconda', 'Georgia'),
#  ('Mean Girls', 'Joan'),
#  ('Mean Girls', 'Lee'),
#  ('The Matrix', 'Frida'),
#  ('The Matrix', 'Pablo'),
#  ('Claude', 'Monty Python and the Holy Grail')]

# %%
plot_graph(B_net)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def answer_one():
    B_net = nx.read_edgelist('Employee_Movie_Choices.txt',delimiter='\t')
    
    return B_net
answer_one()

# %% [markdown]
# ### Question 2
#
# Using the graph from the previous question, add nodes attributes named `'type'` where movies have the value `'movie'` and employees have the value `'employee'` and return that graph.
#
# *This function should return a networkx graph with node attributes `{'type': 'movie'}` or `{'type': 'employee'}`*

# %%
B2 = answer_one()
B2.nodes()[:10]
# Out:
# ['Andy',
#  'Anaconda',
#  'Mean Girls',
#  'The Matrix',
#  'Claude',
#  'Monty Python and the Holy Grail',
#  'Snakes on a Plane',
#  'Frida',
#  'The Shawshank Redemption',
#  'The Social Network']

# %%
B2.edges()[:10]
# Out:
# [('Andy', 'Anaconda'),
#  ('Andy', 'Mean Girls'),
#  ('Andy', 'The Matrix'),
#  ('Anaconda', 'Claude'),
#  ('Anaconda', 'Georgia'),
#  ('Mean Girls', 'Joan'),
#  ('Mean Girls', 'Lee'),
#  ('The Matrix', 'Frida'),
#  ('The Matrix', 'Pablo'),
#  ('Claude', 'Monty Python and the Holy Grail')]

# %%
for node in B2.nodes():
    if node in employees:
        B2.add_node(node , type = 'employee')
    elif node in movies:
        B2.add_node(node , type = 'movie')

# %%
print('num of edges =' ,len(B2.edges(data=True)))
print( 'num of nodes =' ,len(B2.nodes()))
plot_graph(B2)
# Out:
# num of edges = 24
# num of nodes = 19
# <img src="data:image/png;base64,..." width="640">

# %%
B2.nodes(data=True)
# Out:
# [('Andy', {'type': 'employee'}),
#  ('Anaconda', {'type': 'movie'}),
#  ('Mean Girls', {'type': 'movie'}),
#  ('The Matrix', {'type': 'movie'}),
#  ('Claude', {'type': 'employee'}),
#  ('Monty Python and the Holy Grail', {'type': 'movie'}),
#  ('Snakes on a Plane', {'type': 'movie'}),
#  ('Frida', {'type': 'employee'}),
#  ('The Shawshank Redemption', {'type': 'movie'}),
#  ('The Social Network', {'type': 'movie'}),
#  ('Georgia', {'type': 'employee'}),
#  ('Joan', {'type': 'employee'}),
#  ('Forrest Gump', {'type': 'movie'}),
#  ('Kung Fu Panda', {'type': 'movie'}),
#  ('Lee', {'type': 'employee'}),
#  ('Pablo', {'type': 'employee'}),
#  ('The Dark Knight', {'type': 'movie'}),
#  ('Vincent', {'type': 'employee'}),
#  ('The Godfather', {'type': 'movie'})]

# %%
def answer_two():
    B2 = answer_one()
    for node in B2.nodes() : 
        if node in employees:
            B2.add_node(node,type='employee')
        if node in movies :
            B2.add_node(node , type = 'movie')
    
    return B2
answer_two()

# %% [markdown]
# ### Question 3
#
# Find a weighted projection of the graph from `answer_two` which tells us how many movies different pairs of employees have in common.
#
# *This function should return a weighted projected graph.*

# %%
B3 = answer_two()
we_pro_graph = bipartite.weighted_projected_graph(B3 , employees)
plot_graph(we_pro_graph)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
we_pro_graph.edges(data=True)
# Out:
# [('Frida', 'Pablo', {'weight': 2}),
#  ('Frida', 'Andy', {'weight': 1}),
#  ('Frida', 'Vincent', {'weight': 2}),
#  ('Andy', 'Lee', {'weight': 1}),
#  ('Andy', 'Georgia', {'weight': 1}),
#  ('Andy', 'Pablo', {'weight': 1}),
#  ('Andy', 'Joan', {'weight': 1}),
#  ('Andy', 'Claude', {'weight': 1}),
#  ('Vincent', 'Pablo', {'weight': 1}),
#  ('Lee', 'Joan', {'weight': 3}),
#  ('Georgia', 'Claude', {'weight': 3})]

# %%
def answer_three():
    B3 = answer_two()
    we_pro_graph = bipartite.weighted_projected_graph(B3 , employees)

    return we_pro_graph
answer_three()

# %% [markdown]
# ### Question 4
#
# Suppose you'd like to find out if people that have a high relationship score also like the same types of movies.
#
# Find the Pearson correlation ( using `DataFrame.corr()` ) between employee relationship scores and the number of movies they have in common. If two employees have no movies in common it should be treated as a 0, not a missing value, and should be included in the correlation calculation.
#
# *This function should return a float.*

# %% [markdown]
# ## 1: we'll use the relationship score between empolyees:

# %%
relations = pd.read_csv('Employee_Relationships.txt' , sep='\t' ,
            header=None ,names= ['From' , 'To' , 'rela_score'])
relations.head(3)
# Out:
#    From       To  rela_score
# 0  Andy   Claude           0
# 1  Andy    Frida          20
# 2  Andy  Georgia         -10

# %% [markdown]
# ## 2: The number of movies in common we got from the previous Q:

# %%
G  = answer_three()
G.edges(data=True)
# Out:
# [('Frida', 'Pablo', {'weight': 2}),
#  ('Frida', 'Andy', {'weight': 1}),
#  ('Frida', 'Vincent', {'weight': 2}),
#  ('Andy', 'Lee', {'weight': 1}),
#  ('Andy', 'Georgia', {'weight': 1}),
#  ('Andy', 'Pablo', {'weight': 1}),
#  ('Andy', 'Joan', {'weight': 1}),
#  ('Andy', 'Claude', {'weight': 1}),
#  ('Vincent', 'Pablo', {'weight': 1}),
#  ('Lee', 'Joan', {'weight': 3}),
#  ('Georgia', 'Claude', {'weight': 3})]

# %%
G_df1 = pd.DataFrame(G.edges(data=True) ,
                    columns= ['From' , 'To' , 'common_movies'])
# removing the word 'weight'.
G_df1['common_movies'] = G_df1['common_movies'].map(lambda x: x['weight'])
G_df1.head(3)
# Out:
#     From       To  common_movies
# 0  Frida    Pablo              2
# 1  Frida     Andy              1
# 2  Frida  Vincent              2

# %% [markdown]
# ### - we want to create a df in an interchangeable manner:
#         ** where `Frida TO Pablo` =  `Pablo TO Frida `= 2 **

# %%
G_df2 = pd.DataFrame(G.edges(data=True) ,
                    columns= ['To' , 'From' , 'common_movies'])
# removing the word 'weight'.
G_df2['common_movies'] = G_df2['common_movies'].map(lambda x: x['weight'])
G_df2.head(3)
# Out:
#       To     From  common_movies
# 0  Frida    Pablo              2
# 1  Frida     Andy              1
# 2  Frida  Vincent              2

# %%
# finally , use concat() to put them on each other in one dataframe.
G_df = pd.concat([G_df1,G_df2] ,axis=0,ignore_index = True)

# check:
G_df.tail(11)
# Out:
#        From       To  common_movies
# 11    Pablo    Frida              2
# 12     Andy    Frida              1
# 13  Vincent    Frida              2
# 14      Lee     Andy              1
# 15  Georgia     Andy              1
# 16    Pablo     Andy              1
# 17     Joan     Andy              1
# 18   Claude     Andy              1
# 19    Pablo  Vincent              1
# 20     Joan      Lee              3
# 21   Claude  Georgia              3

# %% [markdown]
# ## 3: merge `relations` & `G_df` dataframes on `From` & `To` columns .

# %%
final_df = pd.merge(relations , G_df , on=['From' ,'To'] , how='outer')
# convert any NaN to 0 in `common_movies` col.
final_df['common_movies'] = final_df['common_movies'].fillna(0)
final_df
# Out:
#        From       To  rela_score  common_movies
# 0      Andy   Claude         0.0            1.0
# 1      Andy    Frida        20.0            1.0
# 2      Andy  Georgia       -10.0            1.0
# 3      Andy     Joan        30.0            1.0
# 4      Andy      Lee       -10.0            1.0
# 5      Andy    Pablo       -10.0            1.0
# 6      Andy  Vincent        20.0            0.0
# 7    Claude    Frida         0.0            0.0
# 8    Claude  Georgia        90.0            3.0
# 9    Claude     Joan         0.0            0.0
# 10   Claude      Lee         0.0            0.0
# 11   Claude    Pablo        10.0            0.0
# 12   Claude  Vincent         0.0            0.0
# 13    Frida  Georgia         0.0            0.0
# 14    Frida     Joan         0.0            0.0
# 15    Frida      Lee         0.0            0.0
# 16    Frida    Pablo        50.0            2.0
# 17    Frida  Vincent        60.0            2.0
# 18  Georgia     Joan         0.0            0.0
# ...

# %%
final_df['common_movies'].corr(final_df['rela_score'])
# Out:
# 0.78839622217334737

# %%
def answer_four():
    relations = pd.read_csv('Employee_Relationships.txt' , sep='\t' ,
                header=None ,names= ['From' , 'To' , 'rela_score'])
    G  = answer_three()
    # 1------------------
    
    G_df1 = pd.DataFrame(G.edges(data=True) ,
                    columns= ['From' , 'To' , 'common_movies'])
    G_df1['common_movies'] = G_df1['common_movies'].map(lambda x: x['weight'])
    # 2------------------
    
    G_df2 = pd.DataFrame(G.edges(data=True) ,
                    columns= ['To' , 'From' , 'common_movies'])
    G_df2['common_movies'] = G_df2['common_movies'].map(lambda x: x['weight'])
    # 3------------------
    
    # finally , use concat() to put them on each other in one dataframe.
    G_df = pd.concat([G_df1,G_df2] ,axis=0,ignore_index = True)
    # merge `relations` & `G_df` .
    final_df = pd.merge(relations , G_df , on=['From' ,'To'] , how='outer')
    # convert any NaN to 0 in `common_movies` col.
    final_df['common_movies'] = final_df['common_movies'].fillna(0)
    # 4-------------------
    
    result = final_df['common_movies'].corr(final_df['rela_score'])
    return result

answer_four()
# Out:
# 0.78839622217334737

# %% [markdown]
# ## other Method:

# %%
Rel = nx.read_edgelist('Employee_Relationships.txt' ,data=[('relationship_score', int)])

G_df = pd.DataFrame(G.edges(data=True), columns=['From', 'To', 'movies_score'])
Rel_df = pd.DataFrame(Rel.edges(data=True), columns=['From', 'To', 'relationship_score'])

G_copy_df = G_df.copy()
G_copy_df.rename(columns={"From":"From1", "To":"From"}, inplace=True)
G_copy_df.rename(columns={"From1":"To"}, inplace=True)

G_final_df = pd.concat([G_df, G_copy_df])

final_df = pd.merge(G_final_df, Rel_df, on = ['From', 'To'], how='right')

def set_value(val):
    if val is np.nan:
        return {'weight': 0}
    else:
        return val

final_df['movies_score'] = final_df['movies_score'].map(set_value)

final_df['movies_score'] = final_df['movies_score'].map(lambda x: x['weight'])
final_df['relationship_score'] = final_df['relationship_score'].map(lambda x: x['relationship_score'])

final_df['movies_score'].corr(final_df['relationship_score'])
# Out:
# 0.78839622217334726
