# %% [markdown]
# # Merging DataFrames.

# %% [markdown]
# ##### in this lecture the aim is how we can merge 2 dataframes but with respect to multiple approatches which are as follows:
# - the full 2 dataframes.
# - the intersected part between them.
# - the ones are in the 1st not in the 2nd.
# - and so forth.

# %%
import pandas as pd

# lets first create our 2 dataFrame.
# staff dataframe
staff_df = pd.DataFrame([{'Name': 'Kelly',
                          'Role': 'Director of HR'},
                         {'Name': 'Sally',
                          'Role': 'Course liasion'},
                         {'Name': 'James',
                          'Role': 'Grader'}])
# lets make the index of staff df `Name`.
staff_df = staff_df.set_index('Name')


#students dataframe
students_df = pd.DataFrame([{'Name':'James',
                             'School':'Business'},
                            {'Name':'Mike',
                             'School':'Law'},
                            {'Name':'Sally',
                             'School':'Engineering'}])
# we index this by `Name` column too.
students_df = students_df.set_index('Name')


staff_df,students_df
# Out:
# (                 Role
#  Name
#  Kelly  Director of HR
#  Sally  Course liasion
#  James          Grader,
#              School
#  Name
#  James     Business
#  Mike           Law
#  Sally  Engineering)

# %%
# As you may notice , sally & james are in both data frames
# and mike & kelly are not.keep in mind that both dataframe are indexed 
# similarly by 'Names'.

# if we want the union which means all the record in both dataframes
pd.merge(staff_df,students_df,how='outer',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
# if we want the intersection which means the students who are staff in
# the same time.
pd.merge(staff_df,students_df,how='inner',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
#so,we are intersted in knowing the staff regardless of being students or NOT
# to do that we'll make left join but keep inn mind the order in the function
# the first df is the left & the second is the right.

pd.merge(staff_df,students_df,how='left',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
# we want to know all the students (roles & schools) regard less of being 
# staff or not but we want all the students.
pd.merge(staff_df,students_df,how='right',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
# instead of "left_index=True,right_index=True" merge has a smar parameter
# called "on" which allows us to set the column that is in both dfs to merge
# on.

# first, lets remove our index in both dfs.
staff_df = staff_df.reset_index()
students_df = students_df.reset_index()

# then, apply the merge using `on` parameter:
pd.merge(staff_df,students_df,how='right',on='Name')
# which has been used the most.
# Out:
#     Name            Role       School
# 0  Sally  Course liasion  Engineering
# 1  James          Grader     Business
# 2   Mike             NaN          Law

# %%
# what if there are confilcts between the 2 dataframes. so lets
# add the location info in both dfs.
staff_df = pd.DataFrame([{'Name': 'Kelly',
                          'Role': 'Director of HR',
                          'Location':'State Street'},
                         {'Name': 'Sally',
                          'Role': 'Course liasion',
                         'Location':'Washington Avenue'},
                         {'Name': 'James',
                          'Role': 'Grader',
                         'Location':'Washington Avenue'}])
# location : office location where we can find the staff person.

students_df = pd.DataFrame([{'Name':'James',
                             'School':'Business',
                            'Location':'1024 Billiard Avenue'},
                            {'Name':'Mike',
                             'School':'Law',
                            'Location':'Fraternity House #22'},
                            {'Name':'Sally',
                             'School':'Engineering',
                            'Location':'512 Wilson Crescent'}])
# location : the students location is their homes' location.

# at this case merge append _x for left & _y for right to defferentiate 
# between these columns.

# so, if we want the staff information regardless they were students or not,
# but if they were , we would want to get their information as well.
pd.merge(staff_df,students_df,how='left',on='Name')
# Out:
#     Name            Role         Location_x       School            Location_y
# 0  Kelly  Director of HR       State Street          NaN                   NaN
# 1  Sally  Course liasion  Washington Avenue  Engineering   512 Wilson Crescent
# 2  James          Grader  Washington Avenue     Business  1024 Billiard Avenue

# %%
#It's quite possible that the first name for students and staff might overlap
# but the last name might not. In this case, we use a list of the multiple
# columns that should be used to join keys from both dataframes on the on
# parameter. Recall that the column name(s) assigned to the on parameter
# needs to exist in both dataframes.

# Here's an example with some new student and staff data
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 
                          'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 
                          'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 
                          'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 
                            'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 
                            'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 
                            'School': 'Engineering'}])

# AS you may see that James Wilde and James Hammond don't match on both keys
# so they are 2 different persons. so we need to identify that using "on".
# if we want inner join.

pd.merge(staff_df,student_df,how='inner',on = ['First Name','Last Name'])
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %%
# If we think of merging as joining "horizontally", meaning we join on 
# similar values in a column found in two dataframes then concatenating is 
# joining "vertically", meaning we put dataframes on top or at the bottom of
# each other.

# this approch used if we have a 3 datasets had the same columns with just 
# updated records over years but had the exact columns so here we can
# concatenate them.

# because the csv files we're working with are messy, I want to supress 
# some of the jupyter warning messages and just tell read_csv to ignore bad
# lines, so I'm going to start the cell with a cell magic called %%capture

# %%
# %%capture
df_2011 = pd.read_csv('data/MERGED2010_11_PP.csv',error_bad_lines=False)
df_2013 = pd.read_csv('data/MERGED2012_13_PP.csv',error_bad_lines=False)

# %%
df_2013.head(2)
# Out:
#    UNITID   OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654  100200    1002             Alabama A & M University      Normal
# 1  100663  105200    1052  University of Alabama at Birmingham  Birmingham
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
#
#    OMAWDP8_NOTFIRSTTIME_POOLED_SUPP  OMENRUP_NOTFIRSTTIME_POOLED_SUPP  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
#
#    OMENRYP_FULLTIME_POOLED_SUPP  OMENRAP_FULLTIME_POOLED_SUPP  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    OMAWDP8_FULLTIME_POOLED_SUPP  OMENRUP_FULLTIME_POOLED_SUPP  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    OMENRYP_PARTTIME_POOLED_SUPP  OMENRAP_PARTTIME_POOLED_SUPP  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    OMAWDP8_PARTTIME_POOLED_SUPP  OMENRUP_PARTTIME_POOLED_SUPP
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
# [2 rows x 1977 columns]

# %%
# see the length of each data frame

print(len(df_2011))
print(len(df_2013))
# Out:
# 7414
# 7793

# %%
frames = [df_2011,df_2013]
master_df = pd.concat(frames)
print(len(master_df))
master_df.head(2)
# Out:
# 15207
#    UNITID   OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654  100200    1002             Alabama A & M University      Normal
# 1  100663  105200    1052  University of Alabama at Birmingham  Birmingham
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
#
#    OMAWDP8_NOTFIRSTTIME_POOLED_SUPP  OMENRUP_NOTFIRSTTIME_POOLED_SUPP  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
#
#    OMENRYP_FULLTIME_POOLED_SUPP  OMENRAP_FULLTIME_POOLED_SUPP  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    OMAWDP8_FULLTIME_POOLED_SUPP  OMENRUP_FULLTIME_POOLED_SUPP  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    OMENRYP_PARTTIME_POOLED_SUPP  OMENRAP_PARTTIME_POOLED_SUPP  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    OMAWDP8_PARTTIME_POOLED_SUPP  OMENRUP_PARTTIME_POOLED_SUPP
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
# [2 rows x 1977 columns]

# %%
# the problem here that we can't know which observations belong to which year
# since they concatenated together here `keys` parameter comes too handy
master_df_with_keys = pd.concat(frames,keys = ['2011','2013'])
master_df_with_keys.head(2)
# Out:
#         UNITID   OPEID  OPEID6                               INSTNM  \
# 2011 0  100654  100200    1002             Alabama A & M University
#      1  100663  105200    1052  University of Alabama at Birmingham
#
#               CITY STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 2011 0      Normal     AL       35762           NaN      NaN     NaN  ...
#      1  Birmingham     AL  35294-0110           NaN      NaN     NaN  ...
#
#         OMAWDP8_NOTFIRSTTIME_POOLED_SUPP  OMENRUP_NOTFIRSTTIME_POOLED_SUPP  \
# 2011 0                               NaN                               NaN
#      1                               NaN                               NaN
#
#         OMENRYP_FULLTIME_POOLED_SUPP  OMENRAP_FULLTIME_POOLED_SUPP  \
# 2011 0                           NaN                           NaN
#      1                           NaN                           NaN
#
#         OMAWDP8_FULLTIME_POOLED_SUPP  OMENRUP_FULLTIME_POOLED_SUPP  \
# 2011 0                           NaN                           NaN
#      1                           NaN                           NaN
#
#         OMENRYP_PARTTIME_POOLED_SUPP  OMENRAP_PARTTIME_POOLED_SUPP  \
# 2011 0                           NaN                           NaN
#      1                           NaN                           NaN
#
#         OMAWDP8_PARTTIME_POOLED_SUPP  OMENRUP_PARTTIME_POOLED_SUPP
# 2011 0                           NaN                           NaN
#      1                           NaN                           NaN
#
# [2 rows x 1977 columns]

# %%
# Now we have the indices as the year so we know what observations are from
# what year. You should know that concatenation also has inner and outer
# method. If you are concatenating two dataframes that do not have identical 
# columns, and choose the outer method, some cells will be NaN. If you choose
# to do inner, then some observations will be dropped due to NaN values. 
# You can think of this as analogous to the left and right joins of 
# the merge() function.

# %% [markdown]
# # Pandas Idioms.

# %% [markdown]
# Python programmers will often suggest that there many ways the language can be used to solve a particular problem:
# - But that some are more appropriate than others. The best solutions are celebrated as Idiomatic Python and there are lots of great examples of this on StackOverflow and other websites.
#
# - A sort of sub-language within Python, Pandas has its own set of idioms. We've alluded to some of these already, such as using vectorization whenever possible, and not using iterative loops if you don't need to.
# - Several developers and users within the Panda's community have used the term __pandorable__ for theseidioms.
#
# I  think it's a great term. So, I wanted to share with you a couple of key features of how you can make your code  pandorable.

# %%
# let's start by bringing our data processing libraries.
import pandas as pd
import numpy as np

# let's bring som timing functionality too.
import timeit

df = pd.read_csv('data/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0     1.030015     0.826644     1.383282     1.724718     0.712594
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
#
# [5 rows x 100 columns]

# %%
# 1. Method chaining.
(df.where(df['SUMLEV'] == 50)
         .dropna()
         .set_index(['STNAME','CTYNAME'])
         .rename(columns = {'ESTIMATESBASE2010':'ESTIMATES BASE 2010'})).head(3)

# what is not pandorable
df = df[df['SUMLEV']== 50]
df.set_index(['STNAME','CTYNAME'],inplace = True)
df.rename(columns = {'ESTIMATESBASE2010':'ESTIMATES BASE 2010'})
df.head(3)
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# STNAME  CTYNAME                                           ...
# Alabama Autauga County            55253            55175  ...
#         Baldwin County           186659           190396  ...
#         Barbour County            27226            27159  ...
#
#                         RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME  CTYNAME
# Alabama Autauga County          7.242091         -2.915927         -3.012349
#         Baldwin County         14.832960         17.647293         21.845705
#         Barbour County         -4.728132         -2.500690         -7.056824
#
#                         RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  \
# STNAME  CTYNAME
# Alabama Autauga County          2.265971         -2.530799     7.606016
#         Baldwin County         19.243287         17.197872    15.844176
#         Barbour County         -3.904217        -10.543299    -4.874741
#
#                         RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# STNAME  CTYNAME
# Alabama Autauga County    -2.626146    -2.722002     2.592270    -2.187333
#         Baldwin County    18.559627    22.727626    20.317142    18.293499
#         Barbour County    -2.758113    -7.167664    -3.978583   -10.543299
#
# [3 rows x 98 columns]

# %%
# let's see which one RUN faster.
def first_approach():
    global df
    return (df.where(df['SUMLEV'] == 50)
           .dropna()
           .set_index(['STNAME','CTYNAME'])
           .rename(columns ={'ESTIMATESBASE2010':'ESTIMATES BASE 2010'} ))

df = pd.read_csv('data/census.csv')

# finally lets calculate the time needed to run this
timeit.timeit(first_approach,number=10)
# Out:
# 0.4481207999997423

# %%
# lets test the second piece of code.
def second_approach():
    global df
    new_df = df[df['SUMLEV'] == 50]
    new_df = new_df.set_index(['STNAME','CTYNAME'])
    new_df.rename(columns = {'ESTIMATESBASE2010':'ESTIMATES BASE 2010'})
    return new_df

df = pd.read_csv('data/census.csv')
timeit.timeit(second_approach,number=10)


# what we found that the stylistic might be waste of time but not always.
# Out:
# 0.06992900000113877

# %%
def min_max(df):
    data = df[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min':np.min(data) , 'max':np.max(data)})

df.apply(min_max,axis= 'columns').head()
# Out:
#        min      max
# 0  4785161  4858979
# 1    54660    55347
# 2   183193   203709
# 3    26489    27341
# 4    22512    22861

# %%
# without just returning a separate series we can just modify the original df
def min_max(df):
    data = df[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    df['max'] = np.max(data)
    df['min'] = np.min(data)
    return df

df = df.apply(min_max,axis='columns').head(2)

# %%
# we can do this using lambada which is frequently used.
columns = ['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012',
           'POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']

# lambda takes whatever in the apply() which is in our case a dataframe 
# so( x = df)  and since we assigned a set of columns to iterate over we 
# can get the desired min and max columns.

df['MAX'] = df.apply(lambda x:np.max(x[columns]),axis = 1)
df['MIN'] = df.apply(lambda x:np.min(x[columns]),axis = 1)
df.head(2)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2015  \
# 0        4779736            4780127          4785161  ...         -0.467369
# 1          54571              54571            54660  ...         -2.530799
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015      max  \
# 0     1.030015     0.826644     1.383282     1.724718     0.712594  4858979
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333    55347
#
#        min      MAX      MIN
# 0  4785161  4858979  4785161
# 1    54660    55347    54660
#
# [2 rows x 104 columns]

# %%
def get_state_region(x):
    northeast = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 
                 'Rhode Island','Vermont','New York','New Jersey','Pennsylvania']
    midwest = ['Illinois','Indiana','Michigan','Ohio','Wisconsin','Iowa',
               'Kansas','Minnesota','Missouri','Nebraska','North Dakota',
               'South Dakota']
    south = ['Delaware','Florida','Georgia','Maryland','North Carolina',
             'South Carolina','Virginia','District of Columbia','West Virginia',
             'Alabama','Kentucky','Mississippi','Tennessee','Arkansas',
             'Louisiana','Oklahoma','Texas']
    west = ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah',
            'Wyoming','Alaska','California','Hawaii','Oregon','Washington']
    
    
    if x in northeast:
        return 'Northeast'
    elif x in midwest:
        return 'Midwest'
    elif x in south:
        return 'South'
    else:
        return 'West'

# %%
# now (x = df['STNAME']) which capable to perform our function on
# you have to be focused while doing lambda.
df['state_region'] = df['STNAME'].apply(lambda x: get_state_region(x) )

# %%
df.head(2)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RNETMIG2011  \
# 0        4779736            4780127          4785161  ...     1.030015
# 1          54571              54571            54660  ...     7.606016
#
#    RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015      max      min  \
# 0     0.826644     1.383282     1.724718     0.712594  4858979  4785161
# 1    -2.626146    -2.722002     2.592270    -2.187333    55347    54660
#
#        MAX      MIN  state_region
# 0  4858979  4785161         South
# 1    55347    54660         South
#
# [2 rows x 105 columns]

# %% [markdown]
# # Group by.

# %% [markdown]
# - Sometimes we want to select data based on groups and understand aggregated data on a group level.
# - We have seen that even though Pandas allows us to iterate over every row in a dataframe, it is geneally very slow to do so.
# - Fortunately Pandas has a groupby() function to speed up such task. The idea behind the groupby() function is that it takes some dataframe, splits it into chunks based on some key values, applies computation on those chunks, then combines the results back together into another dataframe.
# - In pandas this is refered to as the split-apply-combine pattern.
#
# ![group by object](group_by_object.png)
# ![group by object](group_by_object2.png)

# %% [markdown]
# # Splitting

# %%
import pandas as pd
import numpy as np

# let's look at US census data
df = pd.read_csv("data/census.csv")

# exclude state level summarization, which have sum level value of 40.
df = df[df['SUMLEV'] == 50]
df.head(2)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
#
# [2 rows x 100 columns]

# %%
# In the first example for groupby() I want to use the census data.
# Let's get a list of the unique states, then we can iterate over all the 
# states and for each state we reduce the data frame and calculate the
# average. Let's run such task for 3 times and time it. For this we'll use 
# the cell magic function %%timeit

# %%
for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME'] == state).dropna()
                                       ['ESTIMATESBASE2010'])
    print('average pop in {} is equel {}'.format(state,avg))
# Out:
# average pop in Alabama is equel 71345.17910447762
# average pop in Alaska is equel 24491.344827586207
# average pop in Arizona is equel 426153.8
# average pop in Arkansas is equel 38879.44
# average pop in California is equel 642319.0172413794
# average pop in Colorado is equel 78583.1875
# average pop in Connecticut is equel 446764.75
# average pop in Delaware is equel 299312.0
# average pop in District of Columbia is equel 601767.0
# average pop in Florida is equel 280666.01492537314
# average pop in Georgia is equel 60935.10062893082
# average pop in Hawaii is equel 272060.2
# average pop in Idaho is equel 35628.454545454544
# average pop in Illinois is equel 125799.5
# average pop in Indiana is equel 70480.75
# average pop in Iowa is equel 30776.454545454544
# average pop in Kansas is equel 27172.685714285715
# average pop in Kentucky is equel 36161.24166666667
# average pop in Louisiana is equel 70835.609375
# average pop in Maine is equel 83022.5625
# average pop in Maryland is equel 240574.375
# average pop in Massachusetts is equel 467701.21428571426
# average pop in Michigan is equel 119085.89156626505
# average pop in Minnesota is equel 60964.65517241379
# average pop in Mississippi is equel 36196.37804878049
# average pop in Missouri is equel 52077.62608695652
# average pop in Montana is equel 17668.160714285714
# average pop in Nebraska is equel 19638.075268817203
# average pop in Nevada is equel 158864.17647058822
# average pop in New Hampshire is equel 131646.6
# average pop in New Jersey is equel 418663.61904761905
# average pop in New Mexico is equel 62399.757575757576
# average pop in New York is equel 312549.79032258067
# average pop in North Carolina is equel 95356.92
# average pop in North Dakota is equel 12690.396226415094
# average pop in Ohio is equel 131099.14772727274
# average pop in Oklahoma is equel 48722.28571428572
# average pop in Oregon is equel 106418.69444444444
# average pop in Pennsylvania is equel 189595.32835820896
# average pop in Rhode Island is equel 210586.2
# average pop in South Carolina is equel 100552.19565217392
# average pop in South Dakota is equel 12336.227272727272
# average pop in Tennessee is equel 66802.8947368421
# average pop in Texas is equel 99000.41338582677
# average pop in Utah is equel 95306.4827586207
# average pop in Vermont is equel 44696.07142857143
# average pop in Virginia is equel 60158.23308270676
# average pop in Washington is equel 172424.1794871795
# average pop in West Virginia is equel 33691.10909090909
# average pop in Wisconsin is equel 78990.125
# average pop in Wyoming is equel 24511.608695652172

# %%
# df.groupby returns a tuples of 2 values. first the key(state Name)(group),
# second (the column we intersted in )(frame).
for group , frame in df.groupby('STNAME'):

    avg = np.average(frame['ESTIMATESBASE2010'])
    print('average pop in {} is equel {}'.format(group,avg))
# Out:
# average pop in Alabama is equel 71345.17910447762
# average pop in Alaska is equel 24491.344827586207
# average pop in Arizona is equel 426153.8
# average pop in Arkansas is equel 38879.44
# average pop in California is equel 642319.0172413794
# average pop in Colorado is equel 78583.1875
# average pop in Connecticut is equel 446764.75
# average pop in Delaware is equel 299312.0
# average pop in District of Columbia is equel 601767.0
# average pop in Florida is equel 280666.01492537314
# average pop in Georgia is equel 60935.10062893082
# average pop in Hawaii is equel 272060.2
# average pop in Idaho is equel 35628.454545454544
# average pop in Illinois is equel 125799.5
# average pop in Indiana is equel 70480.75
# average pop in Iowa is equel 30776.454545454544
# average pop in Kansas is equel 27172.685714285715
# average pop in Kentucky is equel 36161.24166666667
# average pop in Louisiana is equel 70835.609375
# average pop in Maine is equel 83022.5625
# average pop in Maryland is equel 240574.375
# average pop in Massachusetts is equel 467701.21428571426
# average pop in Michigan is equel 119085.89156626505
# average pop in Minnesota is equel 60964.65517241379
# average pop in Mississippi is equel 36196.37804878049
# average pop in Missouri is equel 52077.62608695652
# average pop in Montana is equel 17668.160714285714
# average pop in Nebraska is equel 19638.075268817203
# average pop in Nevada is equel 158864.17647058822
# average pop in New Hampshire is equel 131646.6
# average pop in New Jersey is equel 418663.61904761905
# average pop in New Mexico is equel 62399.757575757576
# average pop in New York is equel 312549.79032258067
# average pop in North Carolina is equel 95356.92
# average pop in North Dakota is equel 12690.396226415094
# average pop in Ohio is equel 131099.14772727274
# average pop in Oklahoma is equel 48722.28571428572
# average pop in Oregon is equel 106418.69444444444
# average pop in Pennsylvania is equel 189595.32835820896
# average pop in Rhode Island is equel 210586.2
# average pop in South Carolina is equel 100552.19565217392
# average pop in South Dakota is equel 12336.227272727272
# average pop in Tennessee is equel 66802.8947368421
# average pop in Texas is equel 99000.41338582677
# average pop in Utah is equel 95306.4827586207
# average pop in Vermont is equel 44696.07142857143
# average pop in Virginia is equel 60158.23308270676
# average pop in Washington is equel 172424.1794871795
# average pop in West Virginia is equel 33691.10909090909
# average pop in Wisconsin is equel 78990.125
# average pop in Wyoming is equel 24511.608695652172

# %%
df.groupby('STNAME')['ESTIMATESBASE2010'].mean()
# Out:
# STNAME
# Alabama                  71345.179104
# Alaska                   24491.344828
# Arizona                 426153.800000
# Arkansas                 38879.440000
# California              642319.017241
# Colorado                 78583.187500
# Connecticut             446764.750000
# Delaware                299312.000000
# District of Columbia    601767.000000
# Florida                 280666.014925
# Georgia                  60935.100629
# Hawaii                  272060.200000
# Idaho                    35628.454545
# Illinois                125799.500000
# Indiana                  70480.750000
# Iowa                     30776.454545
# Kansas                   27172.685714
# Kentucky                 36161.241667
# Louisiana                70835.609375
# Maine                    83022.562500
# Maryland                240574.375000
# Massachusetts           467701.214286
# Michigan                119085.891566
# Minnesota                60964.655172
# Mississippi              36196.378049
# Missouri                 52077.626087
# Montana                  17668.160714
# Nebraska                 19638.075269
# Nevada                  158864.176471
# New Hampshire           131646.600000
# New Jersey              418663.619048
# New Mexico               62399.757576
# New York                312549.790323
# North Carolina           95356.920000
# North Dakota             12690.396226
# Ohio                    131099.147727
# Oklahoma                 48722.285714
# Oregon                  106418.694444
# Pennsylvania            189595.328358
# Rhode Island            210586.200000
# South Carolina          100552.195652
# South Dakota             12336.227273
# Tennessee                66802.894737
# Texas                    99000.413386
# Utah                     95306.482759
# Vermont                  44696.071429
# Virginia                 60158.233083
# Washington              172424.179487
# West Virginia            33691.109091
# Wisconsin                78990.125000
# Wyoming                  24511.608696
# Name: ESTIMATESBASE2010, dtype: float64

# %%
# This is a bit of a fabricated example but lets say that you have a big
# batch job with lots of processing and you want to work on only a third or 
# so of the states at a given time. We could create some function which 
# returns a number between zero and two based on the first character of the
# state name. Then we can tell group by to use this function to split up our
# data frame. It's important to note that in order to do this you need
# to set the index of the data frame to be the column that you want to group
# by first.

# We'll create some new function called set_batch_number() and if the first 
# letter of the parameter is a capital M we'll return a 0. If it's a capital
# Q we'll return a 1 and otherwise we'll return a 2. Then we'll pass
# this function to the data frame.

# first set the column thaat we want to group by as an index.
df = df.set_index('STNAME')

def set_batch_number(item):
    if item[0] < 'M':
        return 0 
    if item[0] < 'Q':
        return 1
    else :
        return 2

# %%
# the dataframe is supposed to be grouped by according to the batch number 
# and we'll loop through each batch group.

# group: the thing we'll divide our data accordingly 0 or 1 or 2.
# frame: the column we are interested in(column that holds 0,1,2).

for group ,frame in df.groupby(set_batch_number):
    print('There are ' + str(len(frame)) + ' records in group ' 
                       + str(group) + ' for processing.')

# Notice that here we didn't pass in a column name to groupby(). instead i
# set the index to be 'STNAME'. so if no column identifier was passed it'll
# automatically go to the index.
# Out:
# There are 1177 records in group 0 for processing.
# There are 1134 records in group 1 for processing.
# There are 831 records in group 2 for processing.

# %%
import pandas as pd
# let's take a look in airbnb df where there is 2 columns of inerests.
# 'cancellation_policy' & 'review_scores_value'.
df = pd.read_csv('data/listings.csv')
df.head(1)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
#
#   last_scraped                        name  \
# 0   2016-09-07  Sunny Bungalow in the City
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
#
#    reviews_per_month
# 0                NaN
#
# [1 rows x 95 columns]

# %%
# find what are the unique values in each column.
df.cancellation_policy.unique()
# Out:
# array(['moderate', 'flexible', 'strict', 'super_strict_30'], dtype=object)

# %%
df.review_scores_value.unique()
# Out:
# array([nan,  9., 10.,  6.,  8.,  7.,  2.,  4.,  3.,  5.])

# %%
# how i would group by both of these columns? 
# 1st approach make multiindex and just call group by.
df = df.set_index(['cancellation_policy' , 'review_scores_value'])

# when we have a multiindex we need to pass in the levels we are interested
# in grouping by.
for group ,frame in df.groupby(level = (0,1)):
    print(group)
# Out:
# ('flexible', 2.0)
# ('flexible', 4.0)
# ('flexible', 5.0)
# ('flexible', 6.0)
# ('flexible', 7.0)
# ('flexible', 8.0)
# ('flexible', 9.0)
# ('flexible', 10.0)
# ('moderate', 2.0)
# ('moderate', 4.0)
# ('moderate', 6.0)
# ('moderate', 7.0)
# ('moderate', 8.0)
# ('moderate', 9.0)
# ('moderate', 10.0)
# ('strict', 2.0)
# ('strict', 3.0)
# ('strict', 4.0)
# ('strict', 5.0)
# ('strict', 6.0)
# ('strict', 7.0)
# ('strict', 8.0)
# ('strict', 9.0)
# ('strict', 10.0)
# ('super_strict_30', 6.0)
# ('super_strict_30', 7.0)
# ('super_strict_30', 8.0)
# ('super_strict_30', 9.0)
# ('super_strict_30', 10.0)

# %%
# Here we want to customise the groups we have after we made the groups
# with respect to the 1st & 2nd columns.So, what i did was passing a function
# to iterate over the default grouping by that occured in the 
# 1st & 2nd columns as we just saw because df is indexed by them
# THEN,appling the function to produce the desired groups.

def grouping_func(group):
    if group [1] == 10.0:
        return (group[0],'10.0')
    else:
        return (group[0],'not 10.0')

for group , frame in df.groupby(grouping_func):
    print(group)
# Out:
# ('flexible', '10.0')
# ('flexible', 'not 10.0')
# ('moderate', '10.0')
# ('moderate', 'not 10.0')
# ('strict', '10.0')
# ('strict', 'not 10.0')
# ('super_strict_30', '10.0')
# ('super_strict_30', 'not 10.0')

# %%
# let's make it a little bit complex 
# what if we want to categories the hole data frame in terms of the 
# `cancellation` policy and is the `review_scores_value` 10 or not?

def grouping_func(item):
    if item [1] == 10.0:
        return (item[0],'10.0')
    else:
        return (item[0],'not 10.0')

for group , frame in df.groupby(grouping_func):
    print(group)
# Out:
# ('flexible', '10.0')
# ('flexible', 'not 10.0')
# ('moderate', '10.0')
# ('moderate', 'not 10.0')
# ('strict', '10.0')
# ('strict', 'not 10.0')
# ('super_strict_30', '10.0')
# ('super_strict_30', 'not 10.0')

# %%
df.head()
# Out:
#                                                id  \
# cancellation_policy review_scores_value
# moderate            NaN                  12147973
#                     9.0                   3075044
#                     10.0                     6976
#                     10.0                  1436513
# flexible            10.0                  7651065
#
#                                                                    listing_url  \
# cancellation_policy review_scores_value
# moderate            NaN                  https://www.airbnb.com/rooms/12147973
#                     9.0                   https://www.airbnb.com/rooms/3075044
#                     10.0                     https://www.airbnb.com/rooms/6976
#                     10.0                  https://www.airbnb.com/rooms/1436513
# flexible            10.0                  https://www.airbnb.com/rooms/7651065
#
#                                               scrape_id last_scraped  \
# cancellation_policy review_scores_value
# moderate            NaN                  20160906204935   2016-09-07
#                     9.0                  20160906204935   2016-09-07
#                     10.0                 20160906204935   2016-09-07
#                     10.0                 20160906204935   2016-09-07
# flexible            10.0                 20160906204935   2016-09-07
#
#                                                                                   name  \
# cancellation_policy review_scores_value
# moderate            NaN                                     Sunny Bungalow in the City
#                     9.0                              Charming room in pet friendly apt
#                     10.0                              Mexican Folk Art Haven in Boston
#                     10.0                 Spacious Sunny Bedroom Suite in Historic Home
# flexible            10.0                                           Come Home to Boston
#
#                                                                                    summary  \
# cancellation_policy review_scores_value
# moderate            NaN                  Cozy, sunny, family home.  Master bedroom high...
#                     9.0                  Charming and quiet room in a second floor 1910...
#                     10.0                 Come stay with a friendly, middle-aged guy in ...
#                     10.0                 Come experience the comforts of home away from...
# flexible            10.0                 My comfy, clean and relaxing home is one block...
#
#                                                                                      space  \
# cancellation_policy review_scores_value
# moderate            NaN                  The house has an open and cozy feel at the sam...
#                     9.0                  Small but cozy and quite room with a full size...
#                     10.0                 Come stay with a friendly, middle-aged guy in ...
#                     10.0                 Most places you find in Boston are small howev...
# flexible            10.0                 Clean, attractive, private room, one block fro...
#
#                                                                                description  \
# cancellation_policy review_scores_value
# moderate            NaN                  Cozy, sunny, family home.  Master bedroom high...
#                     9.0                  Charming and quiet room in a second floor 1910...
#                     10.0                 Come stay with a friendly, middle-aged guy in ...
#                     10.0                 Come experience the comforts of home away from...
# flexible            10.0                 My comfy, clean and relaxing home is one block...
#
#                                         experiences_offered  \
# cancellation_policy review_scores_value
# moderate            NaN                                none
#                     9.0                                none
#                     10.0                               none
#                     10.0                               none
# flexible            10.0                               none
#
#                                                                      neighborhood_overview  \
# cancellation_policy review_scores_value
# moderate            NaN                  Roslindale is quiet, convenient and friendly. ...
#                     9.0                  The room is in Roslindale, a diverse and prima...
#                     10.0                 The LOCATION: Roslindale is a safe and diverse...
#                     10.0                 Roslindale is a lovely little neighborhood loc...
# flexible            10.0                 I love the proximity to downtown, the neighbor...
#
#                                          ... review_scores_communication  \
# cancellation_policy review_scores_value  ...
# moderate            NaN                  ...                         NaN
#                     9.0                  ...                        10.0
#                     10.0                 ...                        10.0
#                     10.0                 ...                        10.0
# flexible            10.0                 ...                        10.0
#
#                                         review_scores_location  \
# cancellation_policy review_scores_value
# moderate            NaN                                    NaN
#                     9.0                                    9.0
#                     10.0                                   9.0
#                     10.0                                  10.0
# flexible            10.0                                   9.0
#
#                                         requires_license license  \
# cancellation_policy review_scores_value
# moderate            NaN                                f     NaN
#                     9.0                                f     NaN
#                     10.0                               f     NaN
#                     10.0                               f     NaN
# flexible            10.0                               f     NaN
#
#                                         jurisdiction_names instant_bookable  \
# cancellation_policy review_scores_value
# moderate            NaN                                NaN                f
#                     9.0                                NaN                t
#                     10.0                               NaN                f
#                     10.0                               NaN                f
# flexible            10.0                               NaN                f
#
#                                         require_guest_profile_picture  \
# cancellation_policy review_scores_value
# moderate            NaN                                             f
#                     9.0                                             f
#                     10.0                                            t
#                     10.0                                            f
# flexible            10.0                                            f
#
#                                         require_guest_phone_verification  \
# cancellation_policy review_scores_value
# moderate            NaN                                                f
#                     9.0                                                f
#                     10.0                                               f
#                     10.0                                               f
# flexible            10.0                                               f
#
#                                         calculated_host_listings_count  \
# cancellation_policy review_scores_value
# moderate            NaN                                              1
#                     9.0                                              1
#                     10.0                                             1
#                     10.0                                             1
# flexible            10.0                                             1
#
#                                          reviews_per_month
# cancellation_policy review_scores_value
# moderate            NaN                                NaN
#                     9.0                               1.30
#                     10.0                              0.47
#                     10.0                              1.00
# flexible            10.0                              2.25
#
# [5 rows x 93 columns]

# %% [markdown]
# # Applying

# %%
# To this point we have applied very simple processing to our data after
# splitting, really just outputting some print statements to demonstrate how 
# the splitting works. The pandas developers have three broad categories of 
#data processing to happen during the apply step, Aggregation of group data, 
# Transformation of group data, and Filtration of group data.

# %% [markdown]
# # Aggregation

# %%
# The most straight forward apply step is the aggregation of data, and uses
# the method agg() on the groupby object. Thus far we have only iterated 
# through the groupby object, unpacking it into a label (the group name)
# and a  dataframe. But with agg we can pass in a dictionary of the columns
# we are  interested in aggregating along with the function we are looking 
# to apply to aggregate.

# let's reset the index for our airbnb data.
df = df.reset_index()

# now,lets groupby the cancellation_policy and find the average of scores
# in each group.
df.groupby("cancellation_policy").agg({"review_scores_value":np.average})

# so, that didn't seem to work at all. but  after inspecting the output we 
# found the reason is a bunch of NaN. the solution is neglecting the nans
# while calculating the average.
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                             NaN
# moderate                             NaN
# strict                               NaN
# super_strict_30                      NaN

# %%
df.groupby('cancellation_policy').agg({'review_scores_value':
                                        np.nanmean})

# so this seems to work out because we are ingnoring the nans
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                        9.237421
# moderate                        9.307398
# strict                          9.081441
# super_strict_30                 8.537313

# %%
# we can extend this dic to aggregate by multiple functions or 
# multiple columns.
df.groupby('cancellation_policy').agg({'review_scores_value': (np.nanmean,np.nanstd),
                                        'reviews_per_month': np.nanmean})
# Out:
#                     review_scores_value           reviews_per_month
#                                 nanmean    nanstd           nanmean
# cancellation_policy
# flexible                       9.237421  1.096271          1.829210
# moderate                       9.307398  0.859859          2.391922
# strict                         9.081441  1.040531          1.873467
# super_strict_30                8.537313  0.840785          0.340143

# %% [markdown]
# # Transformation

# %%
# Transformation is different from aggregation. where agg() returns a single
# value per column. transform() returns an object that is the same size as
# the group. it's broadcasting over a dataFrame bringing dataframe.this makes
# compining data later easy.

# First, lets definne only the columns we are interested in.
cols = ['cancellation_policy', 'review_scores_value']

# now lets transform it putting it into its own dataframe.
transform_df = df[cols].groupby('cancellation_policy').transform(np.nanmean)

transform_df
# Out:
#       review_scores_value
# 0                9.307398
# 1                9.307398
# 2                9.307398
# 3                9.307398
# 4                9.237421
# ...                   ...
# 3580             9.081441
# 3581             9.081441
# 3582             9.237421
# 3583             9.081441
# 3584             9.237421
#
# [3585 rows x 1 columns]

# %%
# now we can merge these two dataframs.
# first , rename the `review_scores_value` column at the transform_df
# to represent the mean.

transform_df.rename({'review_scores_value': 'mean_review_scores'},axis= 1, inplace=True)
df = df.merge(transform_df,left_index=True,right_index=True)
df.head(2)
# Out:
#   cancellation_policy  review_scores_value        id  \
# 0            moderate                  NaN  12147973
# 1            moderate                  9.0   3075044
#
#                              listing_url       scrape_id last_scraped  \
# 0  https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1   https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
#
#                                 name  \
# 0         Sunny Bungalow in the City
# 1  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description  ...  \
# 0  Cozy, sunny, family home.  Master bedroom high...  ...
# 1  Charming and quiet room in a second floor 1910...  ...
#
#   review_scores_location requires_license license jurisdiction_names  \
# 0                    NaN                f     NaN                NaN
# 1                    9.0                f     NaN                NaN
#
#   instant_bookable require_guest_profile_picture  \
# 0                f                             f
# 1                t                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
#
#   reviews_per_month mean_review_scores
# 0               NaN           9.307398
# 1               1.3           9.307398
#
# [2 rows x 96 columns]

# %%
# we can use this new column to get the difference between the actual score
# and the mean score.
df['mean_diff'] = np.absolute(df['review_scores_value'] - 
                              df['mean_review_scores'])
df.head(2)
# Out:
#   cancellation_policy  review_scores_value        id  \
# 0            moderate                  NaN  12147973
# 1            moderate                  9.0   3075044
#
#                              listing_url       scrape_id last_scraped  \
# 0  https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1   https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
#
#                                 name  \
# 0         Sunny Bungalow in the City
# 1  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description  ... requires_license  \
# 0  Cozy, sunny, family home.  Master bedroom high...  ...                f
# 1  Charming and quiet room in a second floor 1910...  ...                f
#
#   license jurisdiction_names instant_bookable require_guest_profile_picture  \
# 0     NaN                NaN                f                             f
# 1     NaN                NaN                t                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
#
#   reviews_per_month mean_review_scores mean_diff
# 0               NaN           9.307398       NaN
# 1               1.3           9.307398  0.307398
#
# [2 rows x 97 columns]

# %% [markdown]
# # Filtering

# %%
# The GroupBy object has build in support for filtering groups as well.
# It's often that you'll want to group by some feature, then make some
# transformation to the groups, then drop certain groups as part of your
# cleaning routines. The filter() function takes in a function which it 
# applies to each group dataframe and returns either a True or a False,
# depending upon whether that group should
# be included in the results.

# we want those groups which have a mean rating above 9 in the result.
# keep in mind `x = df in lambda`
df.groupby('cancellation_policy').filter(lambda x: np.nanmean(x['review_scores_value']) > 9.2)
# Out:
#      cancellation_policy  review_scores_value        id  \
# 0               moderate                  NaN  12147973
# 1               moderate                  9.0   3075044
# 2               moderate                 10.0      6976
# 3               moderate                 10.0   1436513
# 4               flexible                 10.0   7651065
# ...                  ...                  ...       ...
# 3576            flexible                  NaN  14689681
# 3577            flexible                  NaN  13750763
# 3579            flexible                  NaN  14852179
# 3582            flexible                  NaN  14585486
# 3584            flexible                  NaN  14504422
#
#                                 listing_url       scrape_id last_scraped  \
# 0     https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1      https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# 2         https://www.airbnb.com/rooms/6976  20160906204935   2016-09-07
# 3      https://www.airbnb.com/rooms/1436513  20160906204935   2016-09-07
# 4      https://www.airbnb.com/rooms/7651065  20160906204935   2016-09-07
# ...                                     ...             ...          ...
# 3576  https://www.airbnb.com/rooms/14689681  20160906204935   2016-09-07
# 3577  https://www.airbnb.com/rooms/13750763  20160906204935   2016-09-07
# 3579  https://www.airbnb.com/rooms/14852179  20160906204935   2016-09-07
# 3582  https://www.airbnb.com/rooms/14585486  20160906204935   2016-09-07
# 3584  https://www.airbnb.com/rooms/14504422  20160906204935   2016-09-07
#
#                                                    name  \
# 0                            Sunny Bungalow in the City
# 1                     Charming room in pet friendly apt
# 2                      Mexican Folk Art Haven in Boston
# 3         Spacious Sunny Bedroom Suite in Historic Home
# 4                                   Come Home to Boston
# ...                                                 ...
# 3576   Beautiful loft style bedroom with large bathroom
# 3577        Comfortable Space in the Heart of Brookline
# 3579  Spacious Queen Bed Room Close to Boston Univer...
# 3582                           Gorgeous funky apartment
# 3584                 (K1) Private Room near Harvard/MIT
#
#                                                 summary  \
# 0     Cozy, sunny, family home.  Master bedroom high...
# 1     Charming and quiet room in a second floor 1910...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Come experience the comforts of home away from...
# 4     My comfy, clean and relaxing home is one block...
# ...                                                 ...
# 3576  You'd be living on the top floor of a four sto...
# 3577  Our place is close to Coolidge Corner, Allston...
# 3579  - Grocery: A full-size Star market is 2 minute...
# 3582  Funky little apartment close to public transpo...
# 3584  My place is close to My home is a warm and fri...
#
#                                                   space  \
# 0     The house has an open and cozy feel at the sam...
# 1     Small but cozy and quite room with a full size...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Most places you find in Boston are small howev...
# 4     Clean, attractive, private room, one block fro...
# ...                                                 ...
# 3576                                                NaN
# 3577  This space consists of 2 Rooms and a private b...
# 3579                                                NaN
# 3582  Modern and relaxed space with many facilities ...
# 3584  To ensure a smooth check in: 1. You MUST have ...
#
#                                             description  ... requires_license  \
# 0     Cozy, sunny, family home.  Master bedroom high...  ...                f
# 1     Charming and quiet room in a second floor 1910...  ...                f
# 2     Come stay with a friendly, middle-aged guy in ...  ...                f
# 3     Come experience the comforts of home away from...  ...                f
# 4     My comfy, clean and relaxing home is one block...  ...                f
# ...                                                 ...  ...              ...
# 3576  You'd be living on the top floor of a four sto...  ...                f
# 3577  Our place is close to Coolidge Corner, Allston...  ...                f
# 3579  - Grocery: A full-size Star market is 2 minute...  ...                f
# 3582  Funky little apartment close to public transpo...  ...                f
# 3584  My place is close to My home is a warm and fri...  ...                f
#
#      license jurisdiction_names instant_bookable  \
# 0        NaN                NaN                f
# 1        NaN                NaN                t
# 2        NaN                NaN                f
# 3        NaN                NaN                f
# 4        NaN                NaN                f
# ...      ...                ...              ...
# 3576     NaN                NaN                f
# 3577     NaN                NaN                f
# 3579     NaN                NaN                f
# 3582     NaN                NaN                f
# 3584     NaN                NaN                t
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                f                                f
# 2                                t                                f
# 3                                f                                f
# 4                                f                                f
# ...                            ...                              ...
# 3576                             f                                f
# 3577                             f                                f
# 3579                             f                                f
# 3582                             f                                f
# 3584                             f                                f
#
#      calculated_host_listings_count reviews_per_month mean_review_scores  \
# 0                                 1               NaN           9.307398
# 1                                 1              1.30           9.307398
# 2                                 1              0.47           9.307398
# 3                                 1              1.00           9.307398
# 4                                 1              2.25           9.237421
# ...                             ...               ...                ...
# 3576                              1               NaN           9.237421
# 3577                              1               NaN           9.237421
# 3579                              1               NaN           9.237421
# 3582                              1               NaN           9.237421
# 3584                              3               NaN           9.237421
#
#      mean_diff
# 0          NaN
# 1     0.307398
# 2     0.692602
# 3     0.692602
# 4     0.762579
# ...        ...
# 3576       NaN
# 3577       NaN
# 3579       NaN
# 3582       NaN
# 3584       NaN
#
# [1918 rows x 97 columns]

# %% [markdown]
# # Applying

# %%
# In previous work we wanted to find the average review score of a listing
# and its deviation from the group mean. This was a two step process, first 
# we used transform() on the groupby object and then we had to broadcast to
# create a new column. With apply() we could wrap this logic in one place.

# let's look at US census data
df = pd.read_csv("data/listings.csv")

# get our columns of interest.(opitional)
df = df [['cancellation_policy','review_scores_value']]


def calc_diff_mean_review_scores(df):
    avg = np.nanmean(df['review_scores_value'])
    df['diff_mean'] = np.abs(avg - df['review_scores_value'])
    return df

# now just apply this to the groups.
df.groupby('cancellation_policy').apply(calc_diff_mean_review_scores).head()
# Out:
#   cancellation_policy  review_scores_value  diff_mean
# 0            moderate                  NaN        NaN
# 1            moderate                  9.0   0.307398
# 2            moderate                 10.0   0.692602
# 3            moderate                 10.0   0.692602
# 4            flexible                 10.0   0.762579

# %% [markdown]
# 1. Groupby is a powerful and commonly used tool for data cleaning and data analysis. Once you have grouped the data by some category you have a dataframe of just those values and you can conduct aggregated analsyis on the segments that you are interested.
# ******
# 2. The groupby() function follows a split-apply-combine approach - first the data is split into subgroups, then you can apply some transformation, filtering, or aggregation, then the results are combined automatically by pandas for us.

# %% [markdown]
# # Scales.

# %%
# import our libraries.
import pandas as pd
import numpy as np

#create our dataframe.
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                   index = ['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 
                       'ok', 'ok', 'ok', 'poor', 'poor'],
                    columns = ["Grades"])
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
# since we pass a string values in Grades column the dtype would be an object
df.dtypes
# Out:
# Grades    object
# dtype: object

# %%
# we can tell pandas to change the type to category using astype() function.
df['Grades'].astype("category")
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
# We see now that there are eleven categories, and pandas is aware of what
# those categories are. our data isn't just categorical, but that it's 
# ordered. That is, an A- comes after a B+, and B comes before a B+. We can 
# tell pandas that the data is ordered by first creating a newcategorical
# data type with the list of the categories (in order) and
# the ordered=Trueflag.

my_categories = pd.CategoricalDtype(categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                                    ordered=True)

grades = df['Grades'].astype(my_categories)
grades
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
# SO,now pandas knows that the grades are not only categorical but also knows
# the order of these categories. this can help in the boolean masking with
# comparison operator.

# if we want the grades greater than "c" in un-ordered 'df'
print(df[df['Grades'] > "C"]) 
print("\t")

# if we want the grades greater than "c" in ordered 'grades'
print(grades[grades > "C"]) 

# then we can use any mathematical operators like Min & Max.
# on the ordinal data.
# sometimes it's useful to create a column that tells us the presence of a
# category using 0 & 1, this called apply dummy variable.
# Out:
#      Grades
# ok       C+
# ok       C-
# poor     D+
# poor      D
#
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %% [markdown]
#  - There’s one more common scale-based operation I’d like to talk about, and that’s on converting a scale from something that is on the interval or ratio scale, like a numeric grade, into one which is categorical.
#
# - Now, this might seem a bit counter intuitive to you, since you are losing information about the value. But it’s commonly done in a couple of places. For instance, if you are visualizing the frequencies of categories, this can be an extremely useful approach, and histograms are regularly used with converted interval or ratio data.
# ____
# - In addition, if you’re using a machine learning classification approach on data, you need to be using categorical data, so reducing dimensionality may be useful just to apply a given technique. Pandas has a function called `cut()` which takes as an argument some array-like structure like a column of a dataframe or a series. It also takes a number of bins to be used, and all bins are kept at equal spacing.

# %%
# Lets go back to our census data for an example. We saw that we could 
# group by state, then aggregate to get a list of the average county size by
# state. If we further apply cut to this with, say, ten bins, we can see the
# states listed as categoricals using the average county size.

df = pd.read_csv('data/census.csv')

# get the data to include only the county level.
df = df[df['SUMLEV'] == 50]

# set the index to be state name.
df = df.set_index('STNAME')

df = df.groupby(level=0)['CENSUS2010POP'].agg(np.average)
df.head()
# Out:
# STNAME
# Alabama        71339.343284
# Alaska         24490.724138
# Arizona       426134.466667
# Arkansas       38878.906667
# California    642309.586207
# Name: CENSUS2010POP, dtype: float64

# %%
# creating 10 bins (ranges) that every state average pop should fall into.
pd.cut(df,10)

# Here we see that states like alabama and alaska fall into the same category, while california and the
# disctrict of columbia fall in a very different category.

# Now, cutting is just one way to build categories from your data, and there
# are many other methods. For instance, cut gives you interval data, where
# the spacing between each category is equal sized. But sometimes you want
# to form categories based on frequency – you want the number of items in 
# each bin to the be thesame, instead of the spacing between bins. It really
# depends on what the shape of your data is, and what you’re planning to do
# with it.
# Out:
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# Iowa                      (11706.087, 75333.413]
# Kansas                    (11706.087, 75333.413]
# Kentucky                  (11706.087, 75333.413]
# Louisiana                 (11706.087, 75333.413]
# Maine                    (75333.413, 138330.766]
# Maryland                (201328.118, 264325.471]
# Massachusetts           (453317.529, 516314.881]
# Michigan                 (75333.413, 138330.766]
# Minnesota                 (11706.087, 75333.413]
# Mississippi               (11706.087, 75333.413]
# Missouri                  (11706.087, 75333.413]
# Montana                   (11706.087, 75333.413]
# Nebraska                  (11706.087, 75333.413]
# Nevada                  (138330.766, 201328.118]
# New Hampshire            (75333.413, 138330.766]
# New Jersey              (390320.176, 453317.529]
# New Mexico                (11706.087, 75333.413]
# New York                (264325.471, 327322.823]
# North Carolina           (75333.413, 138330.766]
# North Dakota              (11706.087, 75333.413]
# Ohio                     (75333.413, 138330.766]
# Oklahoma                  (11706.087, 75333.413]
# Oregon                   (75333.413, 138330.766]
# Pennsylvania            (138330.766, 201328.118]
# Rhode Island            (201328.118, 264325.471]
# South Carolina           (75333.413, 138330.766]
# South Dakota              (11706.087, 75333.413]
# Tennessee                 (11706.087, 75333.413]
# Texas                    (75333.413, 138330.766]
# Utah                     (75333.413, 138330.766]
# Vermont                   (11706.087, 75333.413]
# Virginia                  (11706.087, 75333.413]
# Washington              (138330.766, 201328.118]
# West Virginia             (11706.087, 75333.413]
# Wisconsin                (75333.413, 138330.766]
# Wyoming                   (11706.087, 75333.413]
# Name: CENSUS2010POP, dtype: category
# Categories (10, interval[float64]): [(11706.087, 75333.413] < (75333.413, 138330.766] < (138330.766, 201328.118] < (201328.118, 264325.471] ... (390320.176, 453317.529] < (453317.529, 516314.881] < (516314.881, 579312.234] < (579312.234, 642309.586]]

# %% [markdown]
# # Pivot Table.

# %% [markdown]
# - A pivot table is a way of summarizing data in a DataFrame for a particular purpose. It makes heavy use of the aggregation function.
#
# - A pivot table is itself a DataFrame, where the rows represent one variable that you're interested in, the columns another, and the cell's some aggregate value. A pivot table also tends to includes marginal values as well, which are the sums for each column and row.
#
# - This allows you to be able to see the relationship between two variables at just a glance.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/cwurData.csv')
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %% [markdown]
# Q: Try to think about how to create a column named `Rank_Level` like this:
#
# - If the `world_rank` is between 1 and 100, then "First Tier Top University"
# - If the `world_rank` is between 101 and 200, then "Second Tier Top University"
# - If the `world_rank` is between 201 and 300, then "Third Tier Top University"
# - Else："Other Top University"

# %%
def ranking(x):
    if x in range (1,101):
        return 'First Tier Top University'
    elif x in range (101,201):
        return 'Second Tier Top University'
    elif x in range (201,301):
        return 'Third Tier Top University'
    else:
        return 'Other Top University'
    
df['Rank_Level'] = df['world_rank'].apply(lambda x: ranking(x))
df.head(2)
# Out:
#    world_rank                            institution country  national_rank  \
# 0           1                     Harvard University     USA              1
# 1           2  Massachusetts Institute of Technology     USA              2
#
#    quality_of_education  alumni_employment  quality_of_faculty  publications  \
# 0                     7                  9                   1             1
# 1                     9                 17                   3            12
#
#    influence  citations  broad_impact  patents   score  year  \
# 0          1          1           NaN        5  100.00  2012
# 1          4          4           NaN        1   91.67  2012
#
#                   Rank_Level
# 0  First Tier Top University
# 1  First Tier Top University

# %%
for group,frame in df.groupby('Rank_Level'):
    print(group)
    print(len(frame))
# Out:
# First Tier Top University
# 400
# Other Top University
# 1400
# Second Tier Top University
# 200
# Third Tier Top University
# 200

# %%
def create_category(ranking):
    # Since the rank is just an integer, I'll just do a bunch of if/elif statements
    if (ranking >= 1) & (ranking <= 100):
        return "First Tier Top Unversity"
    elif (ranking >= 101) & (ranking <= 200):
        return "Second Tier Top Unversity"
    elif (ranking >= 201) & (ranking <= 300):
        return "Third Tier Top Unversity"
    return "Other Top Unversity"

# Now we can apply this to a single column of data to create a new series
df['Rank_Level'] = df['world_rank'].apply(lambda x: create_category(x))
# And lets look at the result
df.head(2)
# Out:
#    world_rank                            institution country  national_rank  \
# 0           1                     Harvard University     USA              1
# 1           2  Massachusetts Institute of Technology     USA              2
#
#    quality_of_education  alumni_employment  quality_of_faculty  publications  \
# 0                     7                  9                   1             1
# 1                     9                 17                   3            12
#
#    influence  citations  broad_impact  patents   score  year  \
# 0          1          1           NaN        5  100.00  2012
# 1          4          4           NaN        1   91.67  2012
#
#                  Rank_Level
# 0  First Tier Top Unversity
# 1  First Tier Top Unversity

# %%
# what if we want the average score for each Rank_Level
# indexed by the country.here we can use pivot_table() function.
df.pivot_table(values='score',columns='Rank_Level', index = 'country',
               aggfunc=[np.mean]).head(2)
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
#
#
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity
# country
# Argentina                        NaN                      NaN
# Australia                    49.2425                   47.285

# %%
# pivot tables aren't limited to one function , we can pass a list of 
# functions :
df.pivot_table(values='score',columns='Rank_Level', index = 'country',
               aggfunc=[np.mean,np.max]).head(2)
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
#
#                                                                \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity
# country
# Argentina                        NaN                      NaN
# Australia                    49.2425                   47.285
#
#                                amax                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN               45.66
# Australia                     51.61               45.97
#
#
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity
# country
# Argentina                        NaN                      NaN
# Australia                       50.4                    47.47

# %%
df.pivot_table(values='score',columns='Rank_Level', index = 'country',
               aggfunc=[np.mean,np.max],margins=True).head(2)
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# Argentina                        NaN                      NaN  44.672857
# Australia                    49.2425                   47.285  45.825517
#
#                                amax                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN               45.66
# Australia                     51.61               45.97
#
#
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity    All
# country
# Argentina                        NaN                      NaN  45.66
# Australia                       50.4                    47.47  51.61

# %%
# A pivot table is just a multi-level dataframe, and we can access series 
# or cells in the dataframe in a similar way as we do so for a regular 
# dataframe. 

# Let's create a new dataframe from our previous example
new_df=df.pivot_table(values='score', index='country', columns='Rank_Level',
                      aggfunc=[np.mean, np.max], margins=True)
# Now let's look at the index
print(new_df.index)
# And let's look at the columns
print(new_df.columns)
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria',
#        'Canada', 'Chile', 'China', 'Colombia', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Egypt', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Iran',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Lebanon', 'Lithuania',
#        'Malaysia', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Puerto Rico', 'Romania', 'Russia', 'Saudi Arabia',
#        'Serbia', 'Singapore', 'Slovak Republic', 'Slovenia', 'South Africa',
#        'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand',
#        'Turkey', 'USA', 'Uganda', 'United Arab Emirates', 'United Kingdom',
#        'Uruguay', 'All'],
#       dtype='object', name='country')
# MultiIndex([('mean',  'First Tier Top Unversity'),
#             ('mean',       'Other Top Unversity'),
#             ('mean', 'Second Tier Top Unversity'),
#             ('mean',  'Third Tier Top Unversity'),
#             ('mean',                       'All'),
#             ('amax',  'First Tier Top Unversity'),
#             ('amax',       'Other Top Unversity'),
#             ('amax', 'Second Tier Top Unversity'),
#             ('amax',  'Third Tier Top Unversity'),
#             ('amax',                       'All')],
#            names=[None, 'Rank_Level'])

# %%
print(new_df['mean']['First Tier Top Unversity'].head(2))
print('\t')
# it's a Series Object type.
print(type(new_df['mean']['First Tier Top Unversity'].head(2) ))
# Out:
# country
# Argentina        NaN
# Australia    47.9425
# Name: First Tier Top Unversity, dtype: float64
#
# <class 'pandas.core.series.Series'>

# %%
# what if we want the country that has the max average for `First Tier..`
# we can do so using idxmax() function.
new_df['mean']['First Tier Top Unversity'].idxmax()

# idxmax() function is a built in func for Series Object.
# Out:
# 'United Kingdom'

# %%
# lets take a look in the df
new_df.head(2)
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# Argentina                        NaN                      NaN  44.672857
# Australia                    49.2425                   47.285  45.825517
#
#                                amax                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN               45.66
# Australia                     51.61               45.97
#
#
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity    All
# country
# Argentina                        NaN                      NaN  45.66
# Australia                       50.4                    47.47  51.61

# %%
# now lets try stack() ond unstack()
new_df = new_df.stack().head(5)
new_df
# Out:
#                                           mean   amax
# country   Rank_Level
# Argentina Other Top Unversity        44.672857  45.66
#           All                        44.672857  45.66
# Australia First Tier Top Unversity   47.942500  51.61
#           Other Top Unversity        44.645750  45.97
#           Second Tier Top Unversity  49.242500  50.40

# %%
# lets get back the original form using unstack():
new_df.unstack().head(5)
# Out:
#                           mean                                      \
# Rank_Level Other Top Unversity        All First Tier Top Unversity
# country
# Argentina            44.672857  44.672857                      NaN
# Australia            44.645750        NaN                  47.9425
#
#                                                     amax         \
# Rank_Level Second Tier Top Unversity Other Top Unversity    All
# country
# Argentina                        NaN               45.66  45.66
# Australia                    49.2425               45.97    NaN
#
#
# Rank_Level First Tier Top Unversity Second Tier Top Unversity
# country
# Argentina                       NaN                       NaN
# Australia                     51.61                      50.4

# %%
# what if we unstacked twice 
new_df.unstack().unstack()
# we actually end up with a series object.
# Out:
#       Rank_Level                 country
# mean  Other Top Unversity        Argentina    44.672857
#                                  Australia    44.645750
#       All                        Argentina    44.672857
#                                  Australia          NaN
#       First Tier Top Unversity   Argentina          NaN
#                                  Australia    47.942500
#       Second Tier Top Unversity  Argentina          NaN
#                                  Australia    49.242500
# amax  Other Top Unversity        Argentina    45.660000
#                                  Australia    45.970000
#       All                        Argentina    45.660000
#                                  Australia          NaN
#       First Tier Top Unversity   Argentina          NaN
#                                  Australia    51.610000
#       Second Tier Top Unversity  Argentina          NaN
#                                  Australia    50.400000
# dtype: float64

# %% [markdown]
# - So that's pivot tables. This has been a pretty short description, but they're incredibly useful when dealing with numeric data, especially if you're trying to summarize the data in some form.
# - You'll regularly be creating new pivot tables on slices of data, whether you're exploring the data yourself or preparing data for others to report on.
# - And of course, you can pass any function you want to the aggregate function,including those that you define yourself.

# %% [markdown]
# # Date/Time Functionality.

# %% [markdown]
# pandas has 4 main time related classes:
# - Timestamp, DatetimeIndex, Period, PeriodIndex.

# %% [markdown]
# ## Timestamp

# %%
# it represents a single timestamp and associates values with points in time.
pd.Timestamp('9/1/2019 10:05AM')
# Out:
# Timestamp('2019-09-01 10:05:00')

# %%
# we can also create timestamp by passing multiple parameters such as year,
# month, date, hour, minute, separately.
pd.Timestamp(2019,12,20,0,0)
# Out:
# Timestamp('2019-12-20 00:00:00')

# %%
# timestamp also has some useful attributes, such as isoweekday(), which
# shows the weekday of the timestamp (1:monday, 7:sunday)
pd.Timestamp(1998,5,9,0,0).isoweekday()
# Out:
# 6

# %%
# we can extract the specific year, month, day, hour, minute, second from a 
# timestamp:
pd.Timestamp(2019,12,20,5,2,23).second
# Out:
# 23

# %% [markdown]
# ## Period

# %%
# suppose we weren't interested in a specific point of time instead we wanted
# a span of time.this where the period class comes into play.
# Period represents a single time span, such as a specific day or month.

# here we are creating a period that is a month wich is january 2016:
pd.Period('1/2016')
# 'M' represents month.
# Out:
# Period('2016-01', 'M')

# %%
# lets create a period of day (March 5th , 2016).
pd.Period('3/5/2016')
# Out:
# Period('2016-03-05', 'D')

# %%
# Arithmetic on period is easy and intuitive, lets add 5 months January2016
pd.Period('1/2016') + 5
# Out:
# Period('2016-06', 'M')

# %%
# if we want to get 2 days before March 5th, 2016.
pd.Period('3/5/2016') - 2

# the key here is that the period object encapsulates
# the granularity('M','D') for arithmetic.
# Out:
# Period('2016-03-03', 'D')

# %% [markdown]
# ## DatetimeIndex & PeriodIndex

# %%
# we'll use the Timestamp of september 1st,2nd,3rd 2016. when we look at the 
# Series , each timestamp is the index which has a value associated with it.
t1 = pd.Series(list('abc'), [pd.Timestamp('2016-09-1'),
                             pd.Timestamp('2016-09-2'),
                             pd.Timestamp('2016-09-3')])
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
type(t1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# Similarly we can create a period-based index as well.
t2 = pd.Series(list('def'), [pd.Period('2016-09'),
                             pd.Period('2016-10'),
                             pd.Period('2016-11')])
t2
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object

# %%
type(t2.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %% [markdown]
# ## Converting to Datetime

# %%
# suppose we have a list of dates as strings and we want to create a new data
# frame.
d1 = ['2 June 2013','Aug 29, 2014','2015-06-26','7/12/16']

# create random DataFrame indexed with the dates above.
t3 = pd.DataFrame(np.random.randint(10,100,(4,2)),
                  index= d1 , columns=list('ab'))
t3
# Out:
#                a   b
# 2 June 2013   51  22
# Aug 29, 2014  64  34
# 2015-06-26    80  84
# 7/12/16       15  95

# %%
# using pandas to_datetime(), pandas will try to convert these to a standard
# format of DateTime.
t3.index  = pd.to_datetime(t3.index)
t3
# Out:
#              a   b
# 2013-06-02  51  22
# 2014-08-29  64  34
# 2015-06-26  80  84
# 2016-07-12  15  95

# %%
# pd.to_datetime() has a parameters to change the date parse order.
# dayfirst = True for European date.
pd.to_datetime('4.7.12' , dayfirst= True)
# Out:
# Timestamp('2012-07-04 00:00:00')

# %% [markdown]
# ## Timedelta

# %%
# timedeltas are differences in times.
# month/ day/ year.
pd.Timestamp('9/3/2016') - pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
# we can find the date & time after 12 days and 3 hours:
pd.Timestamp('9/2/2016 8:10AM') + pd.Timedelta('12D 3H')
# Out:
# Timestamp('2016-09-14 11:10:00')

# %% [markdown]
# ## Offset

# %%
# Offset is similar to timedelta, but it follows specific calendar duration
# rules. Offset allows flexibility in terms of types of time intervals.
# Besides hour, day, week, month, etc it also has business day, end of month,
# semi month begin etc.

pd.Timestamp('9/4/2016').weekday() 

# gives the order of the day in weekdays.
# Out:
# 6

# %%
# we can add the timestamp with a week a head
pd.Timestamp('9/4/2016') + pd.offsets.Week()
# Out:
# Timestamp('2016-09-11 00:00:00')

# %%
# we can also get the month end , to get the last daya in september
pd.Timestamp('9/4/2016') + pd.offsets.MonthEnd()
# Out:
# Timestamp('2016-09-30 00:00:00')

# %% [markdown]
# ## Working with Dates in a DataFrame.

# %%
# Next, let's look at a few tricks for working with dates in a DataFrame.
# Suppose we want to look at nine measurements, taken bi-weekly, every Sunday
# starting in October 2016. Using date_range, we can create this
# DatetimeIndex.

#In data_range, we have to either specify the start or end date. If it is not
# explicitly specified, by default, the date is considered the start date.
# Then we have to specify number of periods, and a frequency. Here, we set it
# to "2W-SUN", which means every 2 weeks on Sunday.

dates = pd.date_range('10-01-2016', periods= 9 ,freq='2W-SUN')
dates
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
# lets try to make a list of dates within BUSINESS DAYS:
# A business day is normally Monday through Friday, from 9 a.m. to 5 p.m.,
# excluding holidays.
Business_dates = pd.date_range('10-01-2016',periods=9,freq='B')
Business_dates
# Out:
# DatetimeIndex(['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06',
#                '2016-10-07', '2016-10-10', '2016-10-11', '2016-10-12',
#                '2016-10-13'],
#               dtype='datetime64[ns]', freq='B')

# %%
# we can do it quartely, with the quarter starts in June.
# we want the date range to be 12 period the difference between each one is 
# year Quarter (3 months) starting from JUNE(6).

pd.date_range('04-01-2016',periods=12 , freq= 'QS-JUN')
# Out:
# DatetimeIndex(['2016-06-01', '2016-09-01', '2016-12-01', '2017-03-01',
#                '2017-06-01', '2017-09-01', '2017-12-01', '2018-03-01',
#                '2018-06-01', '2018-09-01', '2018-12-01', '2019-03-01'],
#               dtype='datetime64[ns]', freq='QS-JUN')

# %%
# Now , lets get back to our Biweekly example on sunday.
dates = pd.date_range('10-01-2016', periods= 9 ,freq='2W-SUN')
df = pd.DataFrame({'count1': 100 + np.random.randint(-5,10,9).cumsum(),
                   'count2': 120 + np.random.randint(-5,10,9)} , index=dates)
df
# Out:
#             count1  count2
# 2016-10-02      96     128
# 2016-10-16      97     121
# 2016-10-30      99     119
# 2016-11-13      95     116
# 2016-11-27      95     118
# 2016-12-11      93     123
# 2016-12-25     100     127
# 2017-01-08     101     128
# 2017-01-22      98     129

# %%
# these give error.
df.index.dt.day_name()
df.index.weekday_name

# %%
# this gives us what we exactly want...

# to check that all days we have is sunday
df = df.reset_index()
df.rename({'index':'timestamp'} ,axis =1 ,inplace = True)

# we know that all the dates in  sunday but lets prove it.
df['day_of_week'] = df.timestamp.dt.day_name()
df

# %%
# we can also use diff() to find the difference between each date's value
df.diff()
# Out:
#             count1  count2
# 2016-10-02     NaN     NaN
# 2016-10-16     1.0    -7.0
# 2016-10-30     2.0    -2.0
# 2016-11-13    -4.0    -3.0
# 2016-11-27     0.0     2.0
# 2016-12-11    -2.0     5.0
# 2016-12-25     7.0     4.0
# 2017-01-08     1.0     1.0
# 2017-01-22    -3.0     1.0

# %%
# suppose we want to get the mean value for each month collectively.
# we can do so using resample() passing 'M' to shrink the df to months
# then mean().

df.resample('M').mean()
# Out:
#                count1      count2
# 2016-10-31  97.333333  122.666667
# 2016-11-30  95.000000  117.000000
# 2016-12-31  96.500000  125.000000
# 2017-01-31  99.500000  128.500000

# %%
# let's look at how to slice and index using timestamp
# first, lets bring our original df
df
# Out:
#             count1  count2
# 2016-10-02      96     128
# 2016-10-16      97     121
# 2016-10-30      99     119
# 2016-11-13      95     116
# 2016-11-27      95     118
# 2016-12-11      93     123
# 2016-12-25     100     127
# 2017-01-08     101     128
# 2017-01-22      98     129

# %%
# slicing using the year
df['2017']
# Out:
#             count1  count2
# 2017-01-08     101     128
# 2017-01-22      98     129

# %%
# slicing using year & month.
df['2016-12']
# Out:
#             count1  count2
# 2016-12-11      93     123
# 2016-12-25     100     127

# %%
# what if we want from `2016-12` onword.
df['2016-12' :]
# Out:
#             count1  count2
# 2016-12-11      93     123
# 2016-12-25     100     127
# 2017-01-08     101     128
# 2017-01-22      98     129

# %% [markdown]
# # QUIZ

# %%
# 1.

#students dataframe
students_df = pd.DataFrame([{'Name':'James',
                             'School':'Business'},
                            {'Name':'Mike',
                             'School':'Law'},
                            {'Name':'Sally',
                             'School':'Engineering'}])
# we index this by `Name` column too.
students_df = students_df.set_index('Name')

# %%
students_df
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
staff_df = pd.DataFrame({'Name':['Kelly','Sally','James'],
              'Role':['DIrector of HR','Course liasion','Grader']})
staff_df = staff_df.set_index('Name')
staff_df
# Out:
#                  Role
# Name
# Kelly  DIrector of HR
# Sally  Course liasion
# James          Grader

# %%
pd.merge(students_df, staff_df, how='left', left_index=True,
         right_index=True)
# Using pd.merge() will select the first DataFrame as the left table and 
# the second DataFrame as the right table. In order to get all records in
# the student_df, we can put it on the left side of 'left' join.
# Out:
#             School            Role
# Name
# James     Business          Grader
# Mike           Law             NaN
# Sally  Engineering  Course liasion

# %%
# 2.
frames = ['P2010', 'P2011', 'P2012', 'P2013','P2014', 'P2015']
df = pd.DataFrame(np.random.randint(10,100,(4,6)),
                   columns= frames)
df
# Out:
#    P2010  P2011  P2012  P2013  P2014  P2015
# 0     34     51     32     10     35     52
# 1     87     72     29     54     70     47
# 2     53     23     12     13     91     34
# 3     28     31     26     24     92     20

# %%
df['AVG'] = df[frames].apply(lambda z: np.mean(z), axis=1)
df
# Out:
#    P2010  P2011  P2012  P2013  P2014  P2015        AVG
# 0     34     51     32     10     35     52  35.666667
# 1     87     72     29     54     70     47  59.833333
# 2     53     23     12     13     91     34  37.666667
# 3     28     31     26     24     92     20  36.833333

# %%
result_df = df.drop(frames,axis=1)
result_df
# Out:
#          AVG
# 0  35.666667
# 1  59.833333
# 2  37.666667
# 3  36.833333

# %%
# 3.
import pandas as pd
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C',
                   'C-', 'D+', 'D'], index=['excellent', 'excellent', 
'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor']
                  , columns = ['Grades'])

df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
my_categories= pd.CategoricalDtype(categories=['D', 'D+', 
        'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'], ordered=True)

grades = df['Grades'].astype(my_categories)
result = grades[(grades>'B') & (grades<'A')]
result
# Out:
# excellent    A-
# good         B+
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
# 4.
df.pivot_table(values='score', index='country', columns='Rank_Level',
               aggfunc=[np.median], margins=True)

# %%
# 5.
import pandas as pd
(pd.Timestamp('11/29/2019') + pd.offsets.MonthEnd()).weekday()
# Out:
# 5

# %%
# 6.
filling_mean = lambda g: g.fillna(g.mean())
type(filling_mean)
# Since it's a function apply() is the best choice.
# Out:
# function

# %%
# 7.
student_df = pd.DataFrame({'First Name':['James','Mike','Sally'],
                         'Last Name' :['Hammond','Smith','Brooks'],
              'School':['Business','Law','Engineering']})

staff_df = pd.DataFrame({'First Name':['Kelly','Sally','James'],
                         'Last Name' :['Desjardins','Brooks','Wilde'],
              'Role':['DIrector of HR','Course liasion','Grader']})


result_df = pd.merge(staff_df,student_df, how='right',
                     on=['First Name', 'Last Name'])
result_df

# Using pd.merge() will select the first DataFrame as the left table
# and the second DataFrame as the right table. In order to get all records
# in the student_df, we can put it on the right side of 'right' join and
# join on both the 'First Name' and 'Last Name' columns.
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering
# 1      James   Hammond             NaN     Business
# 2       Mike     Smith             NaN          Law

# %%
# 8.
df = pd.read_csv('data/listings.csv')
df = df[['name', 'reviews_per_month', 'review_scores_value']]
df.head(5)
# Out:
#                                             name  reviews_per_month  \
# 0                     Sunny Bungalow in the City                NaN
# 1              Charming room in pet friendly apt               1.30
# 2               Mexican Folk Art Haven in Boston               0.47
# 3  Spacious Sunny Bedroom Suite in Historic Home               1.00
# 4                            Come Home to Boston               2.25
#
#    review_scores_value
# 0                  NaN
# 1                  9.0
# 2                 10.0
# 3                 10.0
# 4                 10.0

# %%
df.groupby('review_scores_value').agg({'name': len,
           'reviews_per_month': (np.nanmean, np.nanstd)})
# Out:
#                      name reviews_per_month
#                       len           nanmean    nanstd
# review_scores_value
# 2.0                     7          0.335714  0.431117
# 3.0                     2          0.185000  0.035355
# 4.0                    12          0.605833  0.485751
# 5.0                     2          0.135000  0.007071
# 6.0                    49          0.848776  1.186384
# 7.0                    51          0.823333  0.680978
# 8.0                   334          1.312036  1.593141
# 9.0                  1130          2.327442  2.253361
# 10.0                 1177          2.025123  2.145304

# %%
# 9.
pd.Period('01/12/2019', 'M') + 5
# Out:
# Period('2019-06', 'M')

# %%
# 10.
for group, frame in df.groupby(['name','reviews_per_month'], axis = 0):
    print(group)
# Out:
# (" Cozy Spot in Boston's Little Italy", 5.78)
# (' Getaway in Historic Charlestown', 2.11)
# (' Private Room in a One Family House', 2.92)
# ('"La Gemma" - a gem in the North End', 4.05)
# ('"Room with a View"  from "Top of the Hill"', 0.87)
# ('"The Sheridan" JP, Boston', 0.18)
# ('"Tranquility" on "Top of the Hill"', 2.38)
# ('#2-another room near the airport', 11.48)
# ('#3 Real close to the airport...', 14.34)
# ('#great location #modern living', 0.12)
# ('$125 Special!! Home Away! Condo', 0.54)
# ('$155 Special Fresh! City Loft Apt', 1.36)
# ('$155* L@@K* Cozy Studio Suite! 1.5 miles to center', 0.78)
# ('$165* SPECIAL* 2 bed ApT! Location!', 2.24)
# ('$195 Special! **Sunny** Penthouse Duplex!!  L@@K', 1.83)
# ('$99 Historic Charm Walk to Subway', 0.55)
# ('$99 Special! Hotel Alternative!', 0.4)
# ('$99 Special!!  Historic Comfort', 0.31)
# ('(J1) Private Room near Harvard/MIT', 2.0)
# ('* New 1 BR Financial District Apt *', 0.72)
# ('*$195 SPECIAL*  Historic Beauty!!', 1.11)
# ('**$125 Special!  Bostons Best!!!**', 0.5)
# ('*** Sunny apartment *** near Airport & Train stop', 2.57)
# ('**New** Boston Victorian 3BR Condo', 1.98)
# ('**Studio by Airport and T Station**', 2.74)
# ('*Cosy place near Airport/Downtown and the Beach*', 1.0)
# ('*Fabulous Marlborough St. 1 Bed* :D', 2.83)
# ('+LUXURY BUILDING THAT HAS IT ALL!!!', 1.96)
# ('1 BR / 1 BA Penthouse - South End', 0.66)
# ('1 BR Apt Close to Airport/Train', 0.24)
# ('1 BR Back Bay Public Gardens Apt', 0.12)
# ('1 BR Brownstone Freedom Trail', 0.27)
# ('1 BR Furnished Suite in Boston Harbor View', 1.28)
# ('1 BR Garden Apartment in quiet Neighborhood', 1.0)
# ('1 BR Top Floor Retreat, near Harvard Sq', 4.55)
# ('1 BR apartment located near Harvard University', 3.53)
# ('1 BR in Brighton', 1.94)
# ('1 BR on Newbury St', 0.14)
# ('1 Bd On Water close to Logan', 0.23)
# ('1 Bd Walking Distance to Fenway', 2.63)
# ("1 Bdr Apt on Boston's Fort Hill", 7.75)
# ('1 Bed in Charming Southie Townhouse', 0.37)
# ('1 Bed: Best Location In The City!', 1.1)
# ('1 Bedroom - Entire Place (Seaport)', 3.93)
# ('1 Bedroom Apt Beacon Hill, Boston', 0.54)
# ('1 Bedroom Apt. *B - Boston Back Bay', 1.74)
# ('1 Bedroom Apt. A - Boston Back Bay', 1.06)
# ('1 Bedroom Apt: Downtown/Beacon Hill', 0.85)
# ('1 Bedroom Furnished Suite in Boston Harbor View', 2.0)
# ('1 Bedroom Jamaica Plain', 0.79)
# ('1 Bedroom apartment close to the T', 2.09)
# ('1 Bedroom in Beacon Hill', 1.09)
# ('1 Bedroom in Condominium (III)', 2.31)
# ('1 Bedroom in Furnished Harvard Apt', 0.36)
# ('1 Bedroom in Historic South End', 0.76)
# ('1 Bedroom in Victorian Brownstone', 3.0)
# ('1 Bedroom in a 2 Bedroom Condo', 11.39)
# ('1 Bedroom in heart of Back Bay', 0.16)
# ('1 Bedroom in large Condominium (II)', 2.13)
# ('1 Cozy Room 3mins walk to Train, 5mins to Airport', 10.75)
# ('1 MIN TO BOSTON MARATHON', 0.87)
# ('1 Queen/2 Twin, near Downtown/Ocean', 3.39)
# ('1 Queen/3 Twin-Full, near Downtown/Ocean', 1.0)
# ('1 bd Walking distance to Fenway', 3.68)
# ('1 bed in gorgeous S. Boston Condo', 0.24)
# ('1 bedroom Condo in South Boston', 0.06)
# ('1 bedroom apt in Boston South End', 6.61)
# ('1 bedroom condo in Fort Hill', 0.15)
# ('1 br / 1 ba in the heart of Charlestown', 0.3)
# ('1 br Walking Distance to Fenway', 1.9)
# ('1 br Walking Distance to Fenway', 2.45)
# ('1 br with City Views', 0.83)
# ('1 in 2Br/1Ba near Airport/Downtown.', 4.59)
# ('1 min walk to T, 15 mins to Boston', 0.67)
# ('1 minute walk to subway station', 0.65)
# ('1 room with queen bed in Boston...', 0.3)
# ('10 Min Walk to HBS and Harvard Sq', 0.19)
# ('10 Minutes to Dowtown! Modern New Bedroom', 2.0)
# ('102 Chandler Street by Lyon Apartments', 5.11)
# ('1085 Boylston St. ARTlab, 1 Bed Apt, Boston', 1.04)
# ('1085 Boylston St. ARTlab, 1 Bed Apt, Boston', 1.89)
# ('1085 Boylston St. ARTlab, 1 Bed Apt, Boston', 2.34)
# ('14 Gloucester Street by Lyon Apartments', 2.45)
# ('14 Gloucester Street by Lyon Apartments', 3.06)
# ('14 min to Harvard, MIT, Downtown Crossing and MGH', 0.45)
# ('16 Battery Cindy’s Apartment (#G)', 0.71)
# ('16 Battery McPhee’s Apartment (#1R)', 1.18)
# ('16 Battery Weston’s Apartment (#1F)', 0.53)
# ('1850 Greek Revival House #1', 0.78)
# ('1B apt with sofa bed great location', 2.54)
# ('1BD Brighton condo', 0.33)
# ('1BD in Beacon Hill w. Amazing roof', 0.91)
# ('1BD in Shared Apartment', 1.0)
# ('1BD+PARKING, amazing location!', 8.49)
# ('1BR - 5 min walk from Red MBTA!', 0.55)
# ('1BR 2-5 minutes walk to Red Line!', 0.28)
# ('1BR Apartment - North End', 0.94)
# ('1BR Aptmt in Heart of Dwntn BOS!', 7.12)
# ('1BR Harbor View Furnished Suites', 0.97)
# ('1BR South End/Back Bay Condo', 0.9)
# ('1BR West End Apt. near Restaurants', 0.35)
# ('1BR in Brighton', 0.27)
# ('1BR/ 1BA in 2BR/2BA w/ ocean view', 1.66)
# ('1Beautiful Philadelphia Style Home!', 0.64)
# ('1Studio WalkOutToPatio..CloseToBus,T,HistoricSites', 4.57)
# ('1bd Boston apt - Convenient & quiet', 2.07)
# ('1bd in Boston, close to Fenway!', 1.96)
# ('2 BR 2 Bath Luxury Apmt in SouthEnd', 4.16)
# ('2 BR Apt Boston South End', 0.41)
# ('2 BR Luxury Condo, Downtown Boston', 1.24)
# ('2 BR Modern Loft of Jamaica Plain', 1.8)
# ('2 BR: Back Bay/S End - In the Middle of It All!', 5.9)
# ('2 Bdrm Apt w/ tower in JP Victorian', 1.66)
# ('2 Bed South End-Roof Deck-Dog Park!', 0.15)
# ('2 Bed/ 2 Bath Condo, Boston MA', 1.85)
# ('2 Bed/1 Bath South End at Dog Park!', 1.4)
# ('2 Bedrms, 2 Priv Bath&Priv Entrance', 1.54)
# ('2 Bedroom 2 Bathroom w/Parking Spot', 0.66)
# ('2 Bedroom Apartment in Boston', 4.93)
# ('2 Bedroom Condo near the Red Line ', 0.51)
# ('2 Bedroom Seaport Apartment with City Views!', 3.0)
# ("2 Bedroom Suite - Boston's Back Bay", 0.6)
# ("2 Bedroom in Boston's North End", 0.7)
# ('2 Bedroom in the heart of Boston', 0.44)
# ('2 Bedrooms Near Harvard Square!', 0.08)
# ('2 Bedrooms with 1 private bathroom', 3.85)
# ('2 Br Duplex PH - South End/Back Bay', 0.19)
# ('2 Private Rooms Near T', 0.35)
# ('2 bdrms in JP Victorian', 0.34)
# ('2 bed 1 bath near Downtown & Ocean', 3.78)
# ('2 bed, 2 bath in heart of Boston!', 3.77)
# ('2 bed, great location w/parking!', 0.18)
# ('2 bed,1 bath in the Heart of Boston', 6.98)
# ('2 bed/2 bath in the heart of Boston', 1.1)
# ('2 bedroom Jamaica Plain Egleston Square w/ parking', 1.81)
# ('2 bedroom close to public transit', 2.37)
# ('2 bedroom condo in Downtown Boston', 1.72)
# ('2 bedroom in the heart of Back Bay', 1.0)
# ('2 bedrooms available in 4 bed unit', 2.0)
# ('2 br Walking Distance to Fenway', 2.37)
# ('2 br walking dist. from marathon ❤️', 1.13)
# ('2-Beacon Hill w/PRIVATE DECK, MGH', 2.38)
# ('2-Bed & 2-Bath Apartment in the Heart of Boston!', 2.4)
# ('2/1 Entire Apt Harvard MIT Subway', 2.87)
# ('2/1 Urban Apartment Airport Subway', 2.47)
# ('20% off! Steps to BCEC conv center', 0.68)
# ('2990$ / mo. sunny & renovated 2 BDR in Beacon Hill', 1.11)
# ('2BD Pond-side condo in JP ', 0.15)
# ('2BR 2BA w/AC & Parking', 2.0)
# ('2BR Apt Near T Stops/I95/Boston Logan Airport', 1.0)
# ('2BR BeaconHill Boston Center by Suffolk/MGH/MIT', 1.65)
# ('2BR Downtown Boston', 1.25)
# ('2BR Lux Apt in Downtown', 1.09)
# ('2BR Lux BackBay Apt. by Fenway Park', 0.29)
# ('2BR Luxury Apt - Downtown/West End', 2.34)
# ('2BR PENTHOUSE W/Deck Boston Center', 3.0)
# ('2BR Penthouse Blocks from Fenway', 0.55)
# ('2BR South End Condo w/Big Windows', 2.17)
# ('2BR South End Duplex', 0.18)
# ('2BR in eclectic JP neighborhood', 3.12)
# ('2BR in the Heart of Boston! LF2', 0.69)
# ('2BR with rooftop/South End', 0.77)
# ('2BR/2ba Large North End, perfect location!', 3.64)
# ('2BR: Prettiest Street in Back Bay', 1.63)
# ('2Beautiful Philadelphia Style Home!', 1.11)
# ('2Bed/2Bath with Water & City Views', 1.42)
# ('2Bed2BathDplx 43Bus to BestBosSites', 4.72)
# ('2bdrm Condo Near Train and Airport', 0.34)
# ('2bdrm, Walk to Downtown, Waterfront', 1.88)
# ('2br Lux Apt. in Boston Fenway', 0.43)
# ('2br Lux Apt. in Boston Fenway', 0.64)
# ('2nd floor room in Victorian House', 1.0)
# ('2nd floor, 2 story in Beacon Hill', 2.16)
# ('3 BD single family.  Steps to everything w/ Patio!', 0.96)
# ('3 BR Apartment with Kitchenette', 0.63)
# ('3 BR|2.5 BA Renovated House Parking Top Location', 8.22)
# ('3 Bedroom Condo by Subway & Harbor', 5.69)
# ('3 bed 1 bath near Downtown & Ocean #3', 6.08)
# ('3 bed 1 bath near Downtown/Ocean #2', 5.5)
# ('3 bed, 2 bath, by Downtown/Ocean/Telegraph Hill', 3.57)
# ('3 bedrms, 2 Priv bath', 0.22)
# ('3 bedroom Garden Apt in South End', 2.35)
# ('3 bedroom apartment next to T stop', 7.4)
# ('3 bedrooms in Victorian home.', 1.04)
# ('3 men & a dog 1 room for rent', 0.29)
# ('3 min to T stop-Boston/Somervillle', 1.41)
# ('3 min to subway T stop-Orange Line', 1.79)
# ('3 room country cottage in Boston', 0.26)
# ('3+ bedroom house - center of JP', 0.13)
# ('3-Beacon Hill, MGH,  CableTV, Wifi', 1.46)
# ('3-story Luxury in Central Location', 0.25)
# ('3/1 Harvard MIT Downtown Subway', 3.04)
# ('336 Centre St Boston!', 2.21)
# ('3B2B + parking, Near T, Downtown,Convention Center', 2.0)
# ('3B2B parking,MIT/Havard,BU,Fenway, near 2T station', 2.98)
# ('3BR / 2BA + Prvt Deck in Back Bay', 3.46)
# ('3BR Historic South End Penthouse', 0.21)
# ('3BR/1.5BA + Prvt Patio - Boston', 3.87)
# ('3Bed/2.5Bath Luxury Triplex So. End', 0.97)
# ('3rd floor room in Victorian House', 1.2)
# ('4 Beds 2 Baths in Luxury Brownstone', 0.94)
# ('4 bedroom Victorian Condo unit', 0.95)
# ('4 bedrooms apartment Unit 2', 2.07)
# ('4 minutes walk to the Longwood Medical Area.', 1.0)
# ('4+ BR Quiet, Deluxe, Charming House', 0.75)
# ('4-BEACON HILL, MGH, Fin Dist, BEST!', 3.95)
# ('444 W 4th St', 0.12)
# ('47 Symphony Road, Apt 501', 0.54)
# ('4BD/3.5BA, Perfect for families!', 0.07)
# ('4BR & 2BA Downtown: Combine 2 units', 0.33)
# ('4th floor office room  ', 3.09)
# ('5 mins walk to Longwood Medical Area', 3.29)
# ('5 minutes walk To T Private Room!', 0.56)
# ('5min to Downtown Boston, walk to T ', 5.88)
# ('6 miles away from downtown Boston!', 5.36)
# ('6# Minutes to Boston-Basic Bedroom', 0.29)
# ('6+ Occp Boston, South End/Back Bay', 0.16)
# ('69-3 Minutes to Boston-Near Beach', 1.65)
# ('69-5 Minutes to Boston - Near Beach', 2.75)
# ('7 to 12 minute walk to Prudential', 0.24)
# ('71-1 Minutes to Boston-Near Beach', 1.99)
# ('A Charming spacious room queen bed.', 0.26)
# ('A Cozy Corner of Boston', 1.67)
# ('A HOME AWAY FROM HOME', 0.19)
# ('A Home In The Heart Of It All', 3.33)
# ('A Sunny One Bed Apt', 0.47)
# ('A View of Boston Common', 3.96)
# ('A beautiful house near the bus line', 0.82)
# ('A comfy room in the hills of JP', 4.73)
# ('A cozy room close to Downtown', 3.82)
# ('A cozy room close to Downtown Bosto', 0.47)
# ('A private room at Sunnyside', 3.34)
# ('A quiet and sunny room', 1.99)
# ('A quiet, green oasis in funky JP! ', 2.29)
# ('A room in the heart of Boston', 0.35)
# ('A safe and private place to stay!', 0.91)
# ('A serene, green oasis in funky JP! ', 1.48)
# ('A suburban feel in the city', 0.43)
# ('A sunny room close to Airport', 4.1)
# ('A1. Office/Business Suite', 6.6)
# ('AIR LUXE: APARTMENT @ CORNER OF LUXURY & HISTORY', 1.49)
# ('AMAZING Apt in the center of city!', 1.0)
# ('AMAZING LOCATION - Back Bay/ Symphony', 1.94)
# ('Adorable  Apt. 20 min from Downtown', 0.38)
# ('Adorable 1Bd Apt in Busy Back Bay', 3.62)
# ('Adorable 2BR in heart of Boston', 1.33)
# ('Adorable Beacon Hill One Bedroom', 6.12)
# ('Adorable single family home', 0.81)
# ('Adorable, Cozy Space in JP!', 1.24)
# ('Adventure Houseboat. Free Parking!', 0.67)
# ("Affordable Boston, The dream of the 90's lives.", 1.0)
# ('Affordable Private Room with Airbed', 1.76)
# ('Ahh the Views! 1 Bed with Balcony', 0.27)
# ('Airbed +/- couch in Fenway near Longwood and Hynes', 2.0)
# ('Airbed in Cozy Shared Studio Downtown', 10.0)
# ('Airbnb Apartment Hostel #1', 5.61)
# ('Airbnb Apartment Hostel #2', 6.23)
# ('Airbnb Apartment Hostel #3', 6.0)
# ('Airbnb Apartment Hostel #4', 5.33)
# ('Airbnb Apartment Hostel #5', 7.3)
# ('Airbnb Apartment Hostel #6', 5.4)
# ('Airbnb Apartment Hostel #7', 5.2)
# ('Airy Beacon Hill Flat w City Views', 0.77)
# ('Airy Studio Top of Beacon Hill', 1.76)
# ('All New & Modern 2BR Apt in Boston', 0.4)
# ('Allston Close to Harvard Business E', 2.26)
# ('Allston Close to Harvard Business School + BU C', 4.81)
# ('Allston Red House: By Spare Suite', 0.58)
# ('Allston, Close to Harvard Business School + BU A', 3.42)
# ('Allston, Close to Harvard Business School + BU F', 8.29)
# ('Allston, Close to Harvard Business School + BU G', 4.15)
# ('Allston, Close to Harvard Business School + BU H', 5.37)
# ('Allston, Close to Harvard Business School + BU I', 6.55)
# ('Allston, close to Harvard Business School + BU D', 2.32)
# ('Allston: The Blue Room', 1.71)
# ('Amazing & convenient Charlestown Navy Yard Apt', 5.83)
# ('Amazing 3BR Apt. in heart of C-Town', 0.07)
# ('Amazing Boston Back Bay! GS2', 0.92)
# ('Amazing Design & Detail Throughout!', 0.26)
# ('Amazing Fenway Park Getaway', 5.0)
# ('Amazing Harbor View w/Private Deck', 2.5)
# ('Amazing Newbury St 1 bedroom', 0.54)
# ('Amazing South Boston Apartment', 3.0)
# ('Amazing Two Bedroom w/Boston Skyline Views!', 6.36)
# ('Amazing loft in Brewery', 0.06)
# ('Amazing view near Airport/Downtown', 1.65)
# ('American Vintage room, 2+ peeps ok', 0.07)
# ('An Elegant Condo in Beacon Hill', 4.9)
# ("Andrea's Private Bath T Downtown", 6.23)
# ('Andrew Sq - Quiet Yellow Room', 0.09)
# ('Andrew Sq Room Close to T&Shops', 0.6)
# ('Andrew Sq, South Boston - Modern Condo', 2.64)
# ('Andromeda Houseboat - Free Parking!', 0.72)
# ('Apartment Above Downtown Crossing', 3.4)
# ('Apartment Steps from Boston Common', 1.21)
# ('Apartment close to everything!', 5.69)
# ('Apartment in Fenway', 0.18)
# ('Apartment in Historic South End', 1.74)
# ('Appleton Studio B (M306B) Early Sept DEAL $155/nt', 1.33)
# ('Apt by packards corner! 1 be/1aero', 0.69)
# ('Apt. minutes from Downtown/Airport', 0.36)
# ('Arborside Guest Cottage', 5.93)
# ('Architects Live-in Studio in Boston', 5.87)
# ('Artful + central Allston apartment', 0.69)
# ('Artist 1BR Loft in North End', 10.19)
# ('Artist Studio in SoWa.', 2.13)
# ('Attention to details is our mantra', 0.39)
# ('August sublet in Allston (from 08/03)', 1.0)
# ('Authentic Boston, cozy room', 0.64)
# ('Authentic NORTH END 3br! Lil Italy!', 5.17)
# ('Awesome 1BR in Boston (at Harvard Business School)', 1.0)
# ('Awesome Former Brewery Loft', 1.63)
# ('Awesome Location Beacon Hill Studio', 4.48)
# ('Awesome North End Studio', 2.41)
# ('Awesome Room', 0.07)
# ('Awesome neighborhood close to everything', 6.43)
# ('B1. Cozy in the heart of Boston.', 7.33)
# ('B2. Compact Office Suite w/ Futon', 3.98)
# ('B3. Heart of Boston', 7.03)
# ('BACK BAY FLAT - BEST LOCATION!', 1.41)
# ('BACK BAY, MIT, BU, Green Line, BEST', 2.29)
# ('BACK BAY/COPLEY FIRST FLOOR ROOM', 2.0)
# ('BACKBAY BOSTON', 4.76)
# ('BC,BU sleeps 4,close to T,Boston', 0.92)
# ('BEACON HILL FABULOUS ONE BEDROOM', 3.42)
# ('BEACON HILL SPACIOUS 2BD/2BA UNIT', 0.24)
# ('BEACON HILL, Steps to MGH, Charles', 3.45)
# ('BEAUTIFUL BOSTON BROWNSTONE', 3.67)
# ('BEAUTIFUL VICTORIAN SINGLE FAMILY!', 1.65)
# ('BEST OF BOSTON! 3BD NEAR BCEC!', 7.42)
# ('BMC, Symphony T, NE, BU, Berklee!!', 3.61)
# ('BOSTON - MGH -Beacon Hill- Downtown- great locatio', 0.43)
# ('BOSTON 2BED LOGAN AIRPORT 1st Floor', 4.07)
# ('BOSTON 2BED TOP FLOOR Logan airport', 2.01)
# ('BOSTON COMMON', 1.6)
# ('BOSTON HOME 5 min walk to Train Sta', 4.17)
# ('BOSTON JUST IN FRONT MGH HOSPITAL', 0.87)
# ('BOSTON LUXURY FOR LESS!!! NEAR BCEC', 2.62)
# ('BOSTON ROOM/FREE TRANSIT/BY SUBWAY', 1.13)
# ('BOSTON in Trendy South End', 0.91)
# ('BOSTON, FENWAY, BACKBAY, CAMBRIDGE', 5.66)
# ('BU, Harvard, MIT, Private room', 0.21)
# ('BU/BC Loaded Studio @ Comm/Harv Ave', 5.02)
# ('BU/Harvard/MIT- 3 mins to T', 0.37)
# ('Back Bay - Newbury St 1 bedroom', 1.62)
# ('Back Bay / South End - best of both', 0.09)
# ('Back Bay 1  Bedroom - Charles River', 3.96)
# ('Back Bay 1 Bd Furnished Suite', 0.55)
# ('Back Bay 1 Bedroom near the Pru', 0.58)
# ('Back Bay 1-Bedroom next to Newbury', 1.19)
# ('Back Bay 1BR Apt / Heart of Boston!', 4.09)
# ('Back Bay 2 Bedroom near Pru', 0.89)
# ('Back Bay 2 Bedroom near the Pru', 0.63)
# ('Back Bay 345', 0.74)
# ('Back Bay Apartment', 1.56)
# ('Back Bay Apt - Close and Convenient to Everywhere', 3.67)
# ('Back Bay Beacon 3 Bedroom Bi Level', 2.15)
# ('Back Bay Beacon One Bedroom suite', 1.06)
# ('Back Bay Beacon Two Bedroom', 2.88)
# ('Back Bay Boston Studio', 3.05)
# ('Back Bay Brownstone One Bedroom Apt', 0.48)
# ('Back Bay Elegance in Brighton ', 4.58)
# ('Back Bay Gem 1', 4.54)
# ('Back Bay Gem 2', 4.33)
# ('Back Bay Gem on Commonwealth Avenue', 1.32)
# ('Back Bay Near Fenway, Hynes, the T', 5.08)
# ('Back Bay Newbury St. Designer Apt.', 2.79)
# ('Back Bay PH, private roof deck', 0.61)
# ('Back Bay Penthouse 2 Bed with Private Terrace!', 0.55)
# ('Back Bay Pied a Terre. Fabulous location!', 1.0)
# ('Back Bay Quiet Renovated Studio Apt', 4.91)
# ('Back Bay Shared Room with Young Entrepreneur', 2.09)
# ('Back Bay Studio', 1.04)
# ('Back Bay Studio - PrudentialCenter/Copley/Symphony', 1.25)
# ('Back Bay Studio on Marlborough St-', 0.37)
# ('Back Bay Vacation Rental M234  $225 NOW', 0.71)
# ('Back Bay Vacation Rental Too  M234-2 $185 NOW', 0.54)
# ('Back Bay apartment', 0.94)
# ('Back Bay apt. Close to Marathon!', 1.16)
# ('Back Bay with Style', 0.71)
# ('Back Bay! Best Location in Boston!', 5.85)
# ('Back Bay, Fenway, Newbury, MIT, BU', 3.44)
# ('Back Bay, Newbury St. 1BR', 5.89)
# ('Back Bay, Walking to Convention or Newbury or T!', 1.0)
# ('Back Bay-Ctr BOSTON-Lge Rm Pvt Bath', 1.62)
# ('Back Bay/Copley Sq Brownstone 1 Bed', 1.71)
# ('Back Bay/Downtown Beautiful, Convenient 1 Bedroom', 2.26)
# ('Back bay close to Charles river', 1.09)
# ('Backbay Apt', 0.58)
# ('Baker Chocolate Factory', 0.36)
# ('Ballroom turned loft apartment!', 1.14)
# ("Barney's Master Bedroom T Downtown", 5.07)
# ('Basement apartment in Charlestown', 0.57)
# ('Basic full size room', 3.35)
# ('Be in the Heart of Boston', 1.0)
# ('Beacon Hill', 0.26)
# ('Beacon Hill  1BR Amazing Views', 2.54)
# ('Beacon Hill -Charles Street Studio', 0.82)
# ('Beacon Hill -Charles Street Studio ', 0.96)
# ('Beacon Hill 1BR near Downtown', 2.28)
# ('Beacon Hill 1bed facing Beacon St', 0.09)
# ('Beacon Hill 2 bed 2 bath Penthouse', 2.0)
# ('Beacon Hill 2bed2bath BEST LOCATION', 4.29)
# ('Beacon Hill 3rd Floor 1 BR', 0.43)
# ('Beacon Hill Bed and Breakfast', 0.06)
# ('Beacon Hill Brownstone', 0.71)
# ('Beacon Hill Downtown Sofabed in LR', 1.43)
# ('Beacon Hill Gem! Spacious One Bedroom', 9.55)
# ('Beacon Hill Home / Private Guest Room & Bathroom', 1.0)
# ('Beacon Hill Lux 1BR w/pool & WiFi', 0.39)
# ('Beacon Hill Luxury - Roof Deck!', 0.13)
# ('Beacon Hill Room Available', 1.21)
# ('Beacon Hill Studio', 0.71)
# ('Beacon Hill Studio across from Public Gardens', 3.14)
# ('Beacon Hill Studio w/ patio&parking', 3.12)
# ('Beacon Hill Sunny Studio', 3.47)
# ('Beacon Hill Townhouse', 2.76)
# ('Beacon Hill Townhouse near MGH', 2.24)
# ('Beacon Hill Urban Oasis', 11.68)
# ('Beacon Hill condo w/ outdoor space', 7.89)
# ('Beacon Hill on Charles (#2)', 2.66)
# ('Beacon Hill private studio, near Charles St.', 1.0)
# ('Beacon Hill top floor sunny studio', 0.36)
# ("Beacon Hill's Charles St.", 2.27)
# ('Beacon Hill, 1 private bedroom', 1.73)
# ('Beacon Hill, Boston', 0.37)
# ('Beacon Hill, Charles St, MGH, Red T', 4.16)
# ('Beacon Hill, Guestroom with private bath', 2.72)
# ('Beacon Hill, Steps to Boston Common', 0.76)
# ('Beacon Hill, the Best of Boston!', 3.31)
# ('Beacon Hill- 2br, 2 bath Personal Home', 1.73)
# ('Beacon Street Loft - Amazing Location', 3.0)
# ('Beautiful  1 br/1 bth apartment in Fenway/Back bay', 1.05)
# ('Beautiful 1 BR - Perfect Location', 0.25)
# ('Beautiful 1 Bdrm near Publ Trans.', 0.89)
# ('Beautiful 1 Bed in Back Bay/Fenway', 2.1)
# ('Beautiful 1 Bedroom Condo in Ideal Location!', 1.0)
# ('Beautiful 1 Bedroom Next to Fenway!', 1.02)
# ('Beautiful 1 Bedroom in Beacon Hill', 2.25)
# ('Beautiful 1 Bedroom on Beacon', 0.39)
# ('Beautiful 1 Room Apt at Allston', 1.0)
# ('Beautiful 1 bedroom condo in Boston', 0.08)
# ('Beautiful 1BD North End/Waterfront', 0.17)
# ('Beautiful 1BD in Beacon Hill', 1.74)
# ('Beautiful 1BR in Great Location', 0.7)
# ('Beautiful 1BR-Top BackBay location', 0.21)
# ('Beautiful 2 Bedroom Apt, South End', 1.45)
# ('Beautiful 2 Bedroom North End Apt', 2.13)
# ('Beautiful 2BD / 1 BA - 1st Floor', 2.29)
# ('Beautiful 2BD / 1 BA - 2nd Floor', 3.3)
# ('Beautiful 2BR Downtown Boston! LF2', 0.2)
# ('Beautiful 3 BR with Great Location', 1.42)
# ('Beautiful 3 bd-2 ba  with parking.', 2.3)
# ('Beautiful 3 bedroom Dorchester MA', 2.58)
# ('Beautiful 3BR Boston Location! LF3', 0.96)
# ('Beautiful 3BR Townhouse w/ Garage', 0.81)
# ('Beautiful 4BD/2BA Gem! Near airport, city, subway!', 4.71)
# ('Beautiful Allston room!', 1.0)
# ('Beautiful Apartment in Beacon Hill', 0.21)
# ('Beautiful Apartment in Boston!', 5.39)
# ('Beautiful Apt in a Great Location!', 0.71)
# ('Beautiful Apt/Queen Bed/Near Subway', 5.47)
# ('Beautiful Back Bay 1BR', 0.17)
# ('Beautiful Back Bay Condo! GS2', 0.81)
# ('Beautiful Back Bay One Bed Apt.', 1.34)
# ('Beautiful Back Bay apartment 4 you!', 0.77)
# ('Beautiful Beacon Hill 1 Bedroom', 2.24)
# ('Beautiful Beacon Hill 1 Bedroom', 2.43)
# ('Beautiful Bedroom in the South End', 3.46)
# ('Beautiful Boston 2 Bed Apartment', 0.99)
# ('Beautiful Boston Room-Sunny!', 1.46)
# ('Beautiful Boston Townhouse Living', 0.34)
# ('Beautiful Brownstone Condo', 0.23)
# ('Beautiful Brownstone near Copley Sq', 0.48)
# ('Beautiful Bunker Hill 2 BD', 2.04)
# ('Beautiful City Rental', 0.71)
# ('Beautiful Condo - Centrally Located', 0.2)
# ('Beautiful Condo/Large Private Deck', 1.56)
# ('Beautiful Hilltop Apartments, the end day8/31/16', 2.14)
# ('Beautiful Modern Boston Home', 1.4)
# ('Beautiful New Loft Downtown Boston', 1.31)
# ('Beautiful North End 1BR Apartment', 1.13)
# ('Beautiful Penthouse in Beacon Hill', 0.07)
# ('Beautiful Single-Family Boston Home', 0.56)
# ('Beautiful South End Brownstone', 1.03)
# ('Beautiful South End Brownstone Apartment', 1.0)
# ('Beautiful South End Getaway', 0.56)
# ('Beautiful South End Penthouse!', 5.34)
# ('Beautiful Studio 15 min to Downtown', 0.45)
# ('Beautiful Studio Apt- Symphony area', 4.0)
# ('Beautiful Studio in Beacon Hill', 3.02)
# ('Beautiful Studio in Fenway', 1.07)
# ('Beautiful Studio in South Boston', 1.0)
# ('Beautiful Sunny Bedroom in Boston', 0.16)
# ('Beautiful Victorian House', 0.38)
# ('Beautiful Victorian House /C', 3.3)
# ('Beautiful Victorian House /room B', 2.89)
# ('Beautiful Victorian House/Room D', 2.05)
# ('Beautiful Victorian on Quiet Street', 0.22)
# ('Beautiful Waterfront Location.', 4.81)
# ('Beautiful and sunny condo ', 2.48)
# ('Beautiful apt. in the heart of Beacon Hill', 2.14)
# ('Beautiful bedroom, cozy atmosphere', 3.29)
# ('Beautiful bright corner unit!ioc', 0.59)
# ('Beautiful brownstone great location', 1.93)
# ('Beautiful condo in city point', 1.47)
# ('Beautiful downtown loft for 4', 1.72)
# ('Beautiful flat steps from BackBay', 1.6)
# ('Beautiful house in Jamaica Plain', 1.3)
# ('Beautiful loft by the Orange line!', 0.73)
# ('Beautiful modern condo near T', 0.43)
# ('Beautiful newly renovated apartment', 1.19)
# ('Beautiful one bedroom apartment', 0.31)
# ('Beautiful open concept,private  one bedroom', 0.36)
# ('Beautiful private AC Bedroom/Near T', 11.36)
# ('Beautiful private room in Southie', 3.15)
# ('Beautiful private room in center', 1.94)
# ('Beautiful room in Boston', 0.48)
# ('Beautiful room in hipster town', 2.67)
# ('Beautiful room in the Fenway area', 0.46)
# ('Beautiful view, perfect location!', 2.0)
# ('Beautiful, Expansive Space in JP', 1.46)
# ('Beautiful, Modern, Furnished Apt!', 0.26)
# ('Beautiful, Quiet, and Safe!', 0.16)
# ('Beautiful, Spacious Apt in Allston!', 0.26)
# ('Beautiful, airy room in JP', 0.36)
# ('Beautiful, sunny 1BR apartment in prime location', 2.67)
# ('Beautifully Updated Single Family', 3.0)
# ('Beautifully renovated one bedroom', 1.0)
# ('Beautifully-Appointed 2 Bed floor-thru w/parking', 1.13)
# ('Bed, Bath & Beyond IV in JP', 2.01)
# ('Bed, Bath & Beyond in Jamaica Plain', 3.85)
# ('Bed, Bath and Beyond II in JP', 0.52)
# ('Bed, Bath and Beyond III in JP', 0.07)
# ('Bedroom close to Boston', 0.4)
# ('Bedroom in Heart of Fenway', 3.0)
# ('Bedroom in Spacious Brighton Apartment', 0.46)
# ('Bedroom in Sunny Savin Hill Apartment', 2.28)
# ('Bedroom next to Boston University', 3.32)
# ('Best Boston location, 2BR', 3.23)
# ('Best Boston location, 2BR (M #2)', 2.13)
# ('Best Boston location, 2BR (M #3)', 2.39)
# ('Best Boston location, 2BR (M #4)', 1.3)
# ('Best Boston location, 2BR (M#1)', 2.89)
# ('Best Cozy Freedom trail apartment!!', 6.45)
# ('Best Location in Boston (1-4)', 1.05)
# ('Best Location in Boston (Copley Sq)', 0.83)
# ('Best Location, Luxury Condo', 3.57)
# ('Best location in Boston (Back Bay) opposite MIT', 2.0)
# ('Best value-Cozy, quiet private room', 0.53)
# ('Best view in town - Boston', 4.92)
# ("Beth's Place, feel at home.", 7.37)
# ('Between BU/BC & great for groups', 2.46)
# ('Big Apartment Steps from MBTA!', 0.29)
# ('Big Beautiful Room Near Fenway Park', 0.48)
# ('Big Bedroom for rent.', 0.16)
# ('Big Boston room', 0.32)
# ('Big Room at Brookline Hill in Boston', 4.0)
# ('Big and clean in Amazing location!!', 4.41)
# ('Big cozy room near T', 0.34)
# ('Big room and deck in great location', 0.06)
# ('Big room steps to BCEC conv center!', 0.2)
# ('Big room with two bed/Room A', 3.83)
# ('Bird Street Gated Residence', 1.82)
# ('Blossom', 0.25)
# ('Bohemian bedroom 5 min walk to redline Ashmont T', 0.67)
# ('Bookcase 1bd facing Boston Common', 0.15)
# ('Boston  Best One Bdrm duplex (h2c)', 1.74)
# ('Boston  Little Italy 2 Bdrms  (H2d)', 2.49)
# ('Boston - Fenway Large Studio', 0.21)
# ('Boston -in the center of it ALL!', 1.71)
# ('Boston / Charlestown Apartment', 4.65)
# ('Boston 1BR Lux Furnished Apt', 0.38)
# ('Boston 2 bedroom top floor condo w/balcony!', 1.11)
# ('Boston @ Its Finest', 1.0)
# ('Boston Apartment (North End)', 11.3)
# ('Boston Back Bay Penthouse', 5.0)
# ('Boston Back Bay/Copley Square', 0.71)
# ('Boston Beauty, Walk to C and B line', 0.19)
# ('Boston Best furnished Studio (H2a)', 1.97)
# ('Boston Centrally Located Brownstone', 6.08)
# ('Boston Charm - Condo', 2.25)
# ('Boston Christopher One Bedroom', 0.84)
# ('Boston Christopher Studio Suite', 2.99)
# ('Boston Classic Brownstone Condo/private room', 6.75)
# ('Boston Comfy Room 2, Phase 2', 1.9)
# ('Boston Comfy Room 3, Phase 2', 2.49)
# ('Boston Executive Whole Apartment', 2.33)
# ('Boston Fenway 2BR Furnished Apt.', 0.22)
# ('Boston Fenway furnished 2br apt.', 0.31)
# ('Boston Financial District', 2.0)
# ('Boston Gladstone', 0.52)
# ('Boston Harbor View 1 BR Furnished Suite', 0.43)
# ('Boston Harbor View 1 BR Furnished Suite', 0.44)
# ('Boston Harbor View 1 BR Suite', 0.58)
# ('Boston Harbor View 1BR Furnished Suites', 0.42)
# ('Boston Huge 1BR Best location (h2b)', 1.33)
# ('Boston Huge 2BR Packards Corner St.', 1.87)
# ('Boston Newbury One Bedroom Suite', 0.59)
# ('Boston Newbury Two Bedroom Grand', 2.68)
# ('Boston Oasis!', 0.69)
# ('Boston Penthouse / Seaport District', 0.25)
# ('Boston Proper Duplex Great LOCATION', 2.47)
# ('Boston Room/Free Transit/ By Subway', 7.07)
# ('Boston Seaport 1 BR Suite', 0.26)
# ('Boston South End - Multiple Rooms', 0.84)
# ('Boston South End Niche (M327) Short notice deals', 0.5)
# ('Boston South-End Apt. With Porch', 0.9)
# ('Boston Studio Across from Majestic', 2.35)
# ('Boston University Harvard MIT 2RR', 0.32)
# ('Boston Updated Pad for Your Trip!', 3.81)
# ('Boston Vacation Rental M373', 1.9)
# ('Boston Waterfront Navy Yard Condo', 1.76)
# ('Boston apartment 3 floors and a basement', 1.0)
# ('Boston apartment with 2 double beds', 1.49)
# ('Boston around the block,fenway park', 6.07)
# ('Boston beautiful new Apartment #43end day12/31/16', 2.66)
# ('Boston bedroom near Fenway', 1.5)
# ('Boston comfy room 1, phase 2', 3.33)
# ("Boston's Best Location and View", 0.08)
# ("Boston's Best Newbury Street Flat!!", 1.62)
# ("Boston's Custom House CE's Villa", 0.56)
# ('Boston\'s North End-"Little Italy"', 2.03)
# ('Boston\'s favorite "Little Italy"', 8.71)
# ('Boston, South End - 1 Bedroom (I)', 1.57)
# ('Boston, South End - 3 Bedrooms', 0.26)
# ('Boston/gym/family friendly', 0.35)
# ('Boutique South End, with sunshine', 0.56)
# ('Braddock Suite Studio  M365-ST', 1.96)
# ('Brand NEW South Boston 1 bedroom', 0.89)
# ('Brand New 1 Bed Flat - South Boston', 1.33)
# ('Brand New 1 Bed Flat, South Boston', 1.07)
# ('Brand New 2 BR | 1 BA in So. BOS #1', 3.72)
# ('Brand New 2 BR | 1 BA in So. BOS #2', 3.07)
# ('Brand New 2 BR | 1 BA in So. BOS #3', 3.03)
# ('Brand New 4 BR|2 BA in So. BOS #2+3', 0.85)
# ('Brand New 4BR near Seaport + Ocean!', 1.06)
# ('Brand New Apt in Great Location!', 2.74)
# ('Brand New Beacon Hill Penthouse!', 2.31)
# ('Brand New Luxury 1BR in South End', 0.12)
# ('Brand New One Bedroom in Back Bay', 3.75)
# ('Brand New Renovations, Private Apartment on T!', 2.0)
# ('Brand New! South Boston 1 bedroom', 1.25)
# ('Brand new town house in Brighton, 2 parking spaces', 1.96)
# ('Brand-new corner studio Seaport', 2.66)
# ('Breathtaking downtown arty condo', 0.08)
# ('Bright & Spacious Private Room', 3.08)
# ('Bright & beautiful 2BR in best location', 1.04)
# ('Bright 1 Bedroom n Public Trans.', 1.36)
# ('Bright 1BR in South End w/ Pool+Gym', 2.26)
# ('Bright 1bed facing Golden Dome', 0.25)
# ('Bright 2BR by BC Campus', 1.79)
# ('Bright 2BR in Heart of South End', 2.23)
# ('Bright Apartment Near Everything', 0.35)
# ('Bright Boston Bedroom in Prime Location', 2.0)
# ('Bright Room #4 Close JFK Red Line T Station', 1.0)
# ('Bright Room Near Roslindale Village', 0.21)
# ('Bright South End 1BR w/Gym, Pool', 0.96)
# ('Bright Studio at Commonwealth ave', 0.32)
# ('Bright Studio by Convention Center', 7.48)
# ('Bright and Airy Family Home', 0.23)
# ('Bright and cozy newly renovated 1BR', 3.99)
# ('Bright and very spacious private room', 3.83)
# ('Bright home with lots of character!', 1.69)
# ('Bright room with queen sized bed', 1.32)
# ('Bright spacious room, all welcome!!', 6.48)
# ('Bright, Spacious Loft in North End', 0.07)
# ('Bright, cozy bedroom in Victorian ', 0.22)
# ('Bright, new, modern studio in downtown Boston', 0.68)
# ('Brighton 2BR by BC campus with lake view and AC', 0.71)
# ('Brighton/Allston quiet neighborhood/furnished', 0.7)
# ('Brilliant Former Brewery Apartment', 0.11)
# ('Brimming With Life in Beacon Hill', 3.19)
# ('Brown Stone Apt #4near Northeastern', 0.8)
# ('Brown Stone apartment near Northeastern Univ', 0.54)
# ('Brownstone Apt. in Hip S. End!', 0.58)
# ('Brownstone Cozy Penthouse Suite', 3.52)
# ('Brownstone Cozy Private Studio', 7.41)
# ('Brownstone Custom Bedroom', 1.68)
# ('Brownstone Loft Bedroom', 1.82)
# ('Brownstone Master Bedroom Suite', 3.65)
# ('Brownstone Modern Bedroom ', 3.5)
# ('Brownstone Penthouse near Fenway', 1.24)
# ('Brownstone Serene Guest BR/Bath', 2.96)
# ('Brownstone in heart of Back Bay', 6.29)
# ('Brownstone on Charming Dead End St.', 1.37)
# ('Brownstone with Private Roof Deck!', 0.24)
# ('Budget Double - share bath ', 0.04)
# ('Budget Single - share bath', 0.09)
# ('By Harvard/Cambrdge: Allston/Boston', 1.84)
# ('C1.  2 XL Twins', 6.7)
# ('C2. Middle of Boston', 6.62)
# ('CITY HOME COUNTRY FEEL, Boston, MA USA', 1.0)
# ('COMFY TWIN DOUBLE ROOM IN BOSTON', 5.02)
# ('COPLEY SQ...19TH C.TWNHSE SUNNY RM', 3.46)
# ('COZY 2 BEDROOM IN GREATER BOSTON', 3.67)
# ('COZY 4th fl. historic Beacon Hill', 1.43)
# ('COZY South end studio', 2.0)
# ('Cafe-Style Studio Allston Brookline', 1.25)
# ('Camp Chandler Pond', 9.67)
# ('Canal St. 7th Floor by Spare Suite', 0.48)
# ('Canal Street Indigo: by Spare Suite', 0.48)
# ('Carlyle 5th Floor: by Spare Suite', 0.6)
# ('Carlyle Penthouse: by Spare Suite', 0.52)
# ('Cedars on Beacon Hill One Bedroom', 1.72)
# ('Cedars on Beacon Hill Studio Suite', 2.41)
# ('Center is never closer Estie-Boston', 0.21)
# ('Centered on Centre ', 3.14)
# ('Central Boston Beacon Hill 2brm', 8.85)
# ('Central Private Room in Allston by subway', 0.45)
# ('Central sunny apt. (fun rugs)', 0.42)
# ('Centrally located brownstone on historic Beacon St', 5.27)
# ('Centrally located single room in Fenway/Backbay', 2.0)
# ('Centrally located studio apartment', 1.88)
# ('Centrally located, cozy studio', 0.33)
# ('Charles Regatta - Walk to the River', 0.31)
# ('Charles River gem-Back Bay, Boston', 0.31)
# ('Charles St, Studio Apt, Boston #31', 0.72)
# ('Charles St, Studio Apt, Boston #52', 1.37)
# ('Charlestown 3 Bedroom Townhouse', 2.0)
# ('Charlestown Brownstone', 0.79)
# ('Charlestown Penthouse 3 bedroom/ 2 baths', 0.56)
# ('Charlestown Penthouse w/ roof deck', 1.47)
# ('Charlestown Penthouse w/Private Rooftop Views', 2.67)
# ('Charlesview Suites Back Bay ', 1.26)
# ('Charlesview Suites Beacon Hill ', 0.78)
# ('Charming  Apartment, Jamaica Plain', 5.74)
# ('Charming & cozy 1 bedroom ( 2beds)', 0.64)
# ('Charming 1 BR in Historic Boston', 0.43)
# ('Charming 1 bedroom Apartment in Boston!!!', 1.0)
# ('Charming 1 br in the north end', 1.03)
# ('Charming 1-bedroom in the North End', 1.18)
# ('Charming 1B in the heart North End', 0.71)
# ('Charming 1BD Apt. South Boston', 0.96)
# ('Charming 1BD in house ', 3.55)
# ('Charming 1BD near BU in front of T.', 0.42)
# ('Charming 2-Bedroom in Beacon Hill', 0.43)
# ('Charming 2-Story Flat, Great Value!', 1.16)
# ('Charming 2BD Across from Arboretum', 0.6)
# ('Charming 3 bedroom-15 min to Boston', 2.07)
# ('Charming 3BR in Allston', 2.4)
# ('Charming 3BR, 1BA- 5 min to Boston', 1.83)
# ('Charming Back Bay Brownstone', 1.05)
# ('Charming Back Bay Loft', 0.74)
# ('Charming Bay Village Brownstone Apt', 1.1)
# ('Charming Beacon Hill 1+ BR Condo', 0.13)
# ('Charming Beacon Hill Condo + Patio', 1.85)
# ('Charming Beacon Hill Room + Patio', 3.26)
# ('Charming Bedroom at Family Home', 4.94)
# ('Charming Bedroom in Kenmore', 0.17)
# ('Charming Boston Apartment', 0.47)
# ('Charming Escape in Beacon Hill', 2.12)
# ('Charming Gambrel on a sweet street', 0.59)
# ('Charming Garden Studio In South End', 0.96)
# ('Charming Modern 1 Bed', 1.0)
# ('Charming Modern Home in JP!', 0.35)
# ('Charming North End bedroom', 0.06)
# ('Charming Private Suite w/Patio', 0.89)
# ('Charming Room, Free Parking & WiFi', 4.96)
# ('Charming South Boston 2 BR Condo', 0.34)
# ('Charming South End Apartment', 0.21)
# ('Charming South End Apartment', 0.97)
# ('Charming South End Brownstone Loft', 0.9)
# ('Charming South End, Boston Condo', 0.5)
# ('Charming Studio on Mass Ave.', 2.17)
# ('Charming Studio–Heart of Back Bay!', 2.25)
# ('Charming Victorian Furnished Home', 1.78)
# ('Charming Victorian Home', 2.45)
# ('Charming Victorian near T', 0.48)
# ('Charming and Bright South End Apt', 1.8)
# ('Charming and quiet 1BR in Brighton!', 6.0)
# ('Charming apartment in an artsy area', 0.19)
# ('Charming attic room in Boston', 1.83)
# ('Charming beacon hill apartment', 0.95)
# ('Charming bedroom in cozy apartment', 0.38)
# ('Charming comfort 1 BR / Studio', 0.24)
# ('Charming freedom trail apartment', 6.23)
# ('Charming loft in the North End!', 0.35)
# ('Charming new house-15 min to Boston', 4.32)
# ('Charming private bedroom with bath', 1.0)
# ('Charming room in Boston, MA', 3.61)
# ('Charming room in pet friendly apt', 1.3)
# ('Charming single family home', 0.38)
# ('Charming single family home', 0.72)
# ('Charming south end', 5.34)
# ('Charming south end brownstone', 3.61)
# ('Charming sunlit house in Boston', 0.74)
# ('Charming sunny 2BD near BU/BC', 0.39)
# ('Charming urban studio, free parking', 5.99)
# ('Charming, Cozy 2 br Townhouse', 1.53)
# ('Charming, Cozy, Convenient Home', 3.56)
# ('Charming, Sunny, Convenient 2BR in the South End!', 1.43)
# ('Charming, upscale Beacon Hill home', 0.65)
# ('Cheap, Cozy, Convenient 1BD', 1.97)
# ('Cheery skylit room w/ Queen bed', 1.05)
# ('Chic 1BR in Downtown Boston', 0.7)
# ('Chic 2BR Near Boston Common', 0.98)
# ('Chic 3BR in Lower Roxbury', 1.84)
# ('Chic 3BR in Trendy Allston', 3.0)
# ('Chic Beacon Hill One Bed Apt', 1.73)
# ('Chic home in the heart of Backbay', 0.53)
# ('Chic minimal 2BD in south end SOWA', 0.5)
# ('Chic, Stylish 1 BD on Beacon Hill', 1.51)
# ('Chic, luxury condo, Pool, gym', 0.07)
# ('Chinatown Bedroom', 2.0)
# ('Chinatown Best Location Studio', 2.15)
# ('Chinatown Single Bedroom', 1.15)
# ('Chinatown Single Bedroom', 1.76)
# ('Christmas Room', 0.12)
# ('City and Harbor views', 2.44)
# ('City apartment on the freedom trail', 6.63)
# ('City living near the beach!', 3.59)
# ('City-style, Spacious South End Apt.', 1.4)
# ('CitySide-South Boston', 0.73)
# ('Ck', 4.29)
# ('Classic & Stylish w/ Balcony', 0.23)
# ('Classic 1 bedroom in South End', 1.61)
# ('Classic 2 Bed/1.5 Bath in South End', 1.87)
# ('Classic Back Bay 3 Bed/1 Ba Flat', 1.76)
# ('Classic Beacon Hill Apartment', 1.6)
# ('Classic Boston Brownstone', 0.84)
# ('Classic Boston Townhouse Apartment', 2.69)
# ('Classic Brownstone Walk-Up', 0.48)
# ('Classic Brownstone in Historic Area', 3.18)
# ('Classic South End Brownstone-1 BR', 4.41)
# ('Classic South End One Bedroom', 0.07)
# ('Classic, Quiet Beacon Hill Apt.', 2.31)
# ('Classical Home', 1.0)
# ('Classy Studio in Historic Back Bay', 2.16)
# ('Clean & Quiet Room in Modern Home, Near Transit', 2.57)
# ('Clean 3 Beds apt Charlestown Boston', 0.81)
# ('Clean Apartment in Boston', 2.57)
# ('Clean Comfortable Room in Modern Home Near Transit', 2.04)
# ('Clean Getaway-near BU, BC, Harvard.', 2.97)
# ('Clean Room in the JP Neighborhood', 0.08)
# ('Clean Spacious 1 BR Near T Station', 4.93)
# ('Clean Studio, Great Location', 3.58)
# ('Clean and comfort bedroom', 0.34)
# ('Clean and comfort room near Boston University', 4.0)
# ('Clean and quiet close to T', 0.08)
# ('Clean apartment in trendy JP Boston', 5.0)
# ('Clean bedroom in Allston', 0.14)
# ('Clean spacious room, pvt bathroom, parking & deck', 3.9)
# ('Clean sunny room near Subway', 1.0)
# ('Clean, Comfortable, Convenient and Close to the T', 3.07)
# ('Clean, Convenient and Comfortable', 0.49)
# ('Clean, Hospitable, Back Bay,', 2.29)
# ('Clean, Quiet, and Comfortable', 1.89)
# ('Clean, Sunny, Quiet, 1-Bedroom Apt.', 1.26)
# ('Cleveland Circle Room for the summer', 1.0)
# ('Close to Harvard - Zen Room', 1.83)
# ('Close to airport, downtown Boston', 0.35)
# ('Close to everything in Boston/Cambridge', 1.09)
# ('Close to the Redline in Dorchester!', 0.33)
# ('Close to universities, hospitals', 2.17)
# ('Cloud 9 near Harvard Square', 0.9)
# ('Colorful artist home, prime location!', 0.46)
# ('Columbus Ave By Maverick, FortyFive', 0.13)
# ('Columbus Ave By Maverick, FortyOne', 0.43)
# ('Columbus Ave By Maverick, FortyTwo', 0.34)
# ('Columbus Ave By Maverick, ThirtyOne', 0.35)
# ('Columbus Ave By Maverick, ThirtySix', 0.25)
# ('Columbus Ave By Maverick,ThirtyFour', 0.09)
# ('Columbus Avenue By Maverick, Five', 0.27)
# ('Columbus Avenue By Maverick, Four', 0.25)
# ('Columbus Avenue By Maverick, Seven', 0.09)
# ('Columbus Avenue By Maverick, Six', 0.25)
# ('Columbus Avenue By Maverick, Three', 0.13)
# ('Columbus Avenue By Maverick, Two', 0.19)
# ('Columbus Avenue by Maverick, Eight', 0.13)
# ('Columbus By Maverick, TwentyFour', 0.28)
# ('Come & Explore Beacon Hill!! ', 1.07)
# ('Come Home to Boston', 2.25)
# ('Comfort and peace in the South End.', 3.0)
# ('Comfort in Historic Melville Park 1', 2.14)
# ('Comfort in Historic Melville Park 2', 1.96)
# ('Comfort in Historic Melville Park 3', 0.9)
# ('Comfortable & Convenient in Boston', 1.57)
# ('Comfortable 1 BR in Beacon Hill', 1.51)
# ('Comfortable Brownstone Home', 0.1)
# ('Comfortable Loft - Heart of Boston', 4.52)
# ('Comfortable Private Bedroom for 2', 3.13)
# ('Comfortable Queen Size Bed Room', 5.71)
# ('Comfortable South End Studio', 3.54)
# ('Comfortable Studio in Fenway Area', 0.91)
# ('Comfortable Studio on the Boston Commons', 4.62)
# ('Comfortable and Casual Copely Home', 2.81)
# ('Comfortable furnished room w/Queen bed +amenities.', 0.95)
# ('Comfortable furnished room with high ceilings.', 2.45)
# ('Comfortable one bedroom in Boston Landing', 3.27)
# ('Comfortable quite room.', 0.64)
# ('Comfortable room close to airport', 8.6)
# ('Comfortable room in large apartment', 2.15)
# ('Comfortable room near Subway 14-3b', 1.0)
# ('Comfortable room near redline MBTA subway stop!', 0.37)
# ('Comfortable, Cozy and Value!', 1.17)
# ('Comfortable, Social-friendly Apt', 3.82)
# ('Comfortable, sunny full 2BR condo', 2.76)
# ('Comfy 1 Bedroom, Centrally Located', 0.87)
# ('Comfy 2BR, Amazing Location!', 0.99)
# ('Comfy Couch for short trips!', 6.15)
# ('Comfy Room "A" On a Scenic Hill', 0.16)
# ('Comfy Room (B) On A Scenic Hill', 0.18)
# ('Comfy Room (C) On A Scenic Hill', 0.7)
# ('Comfy Room in the heart of Boston ', 4.53)
# ('Comfy bed, Shared bath, Red line', 4.03)
# ('Comfy couch, Centrally located', 0.67)
# ('Comfy room (C) near T, convention center, downtown', 1.67)
# ('Comfy room b/t Airport & Downtown!', 3.76)
# ('Comfy rooms in the hills of JP', 0.36)
# ('Comfy sofa bed right in the Fenway', 2.31)
# ('Comfy, clean studio in Seaport. Great views!', 3.75)
# ('Comfy, spacious Boston home 3BR/2BA', 4.71)
# ('Comfy, spacious, Downtown 15 min.', 0.53)
# ('Common area bed and sleeping nook', 3.62)
# ('Complete Renovation! BEACON HILL!!', 5.0)
# ('Condo in Back Bay', 0.08)
# ('Condo overlooking Boston Harbour', 0.25)
# ('Convenient & Vibrant South End!  ', 0.33)
# ('Convenient 1 Bedroom Apartment', 0.09)
# ('Convenient 1 bedroom on Tremont St', 1.02)
# ('Convenient 2bd Downtown Apt', 5.31)
# ('Convenient 3bd Near Downtown', 0.22)
# ('Convenient Beacon Hill hideaway', 1.08)
# ('Convenient Boston Hotel Alternative', 0.87)
# ('Convenient Place & Comfortable Room', 1.63)
# ('Convenient Private Room-Downtown Boston, Longwood', 1.0)
# ('Convenient Stay in Chinatown Boston', 5.0)
# ('Convenient Studio in Fenway Area', 0.19)
# ('Convenient green Victorian', 1.83)
# ('Convenient, Sunny 3b/2bth w/Parking', 0.18)
# ('Convention Cent- 10 min walk! BEST!', 5.05)
# ('Convient, Safe and Comfortable', 1.0)
# ("Cookyee's Paradise", 2.9)
# ('Cool Boston Crib. Awesome Building', 3.08)
# ('Cool Place in Allston, Boston.', 0.06)
# ('Coolest new building in Boston', 4.9)
# ('Copley Back Bay Brownstone 1BR', 0.83)
# ('Copley Garrison One Bedroom Suite', 0.25)
# ('Copley Garrison Two Bedroom Suite', 1.84)
# ('Copley Vacation Rental on the Park M325 SPECIAL!', 0.23)
# ('Corner 1 bed facing Golden Dome', 0.24)
# ('Cosy Bedroom by Harvard', 0.16)
# ('Cosy Celtic Retreat', 0.89)
# ('Cosy bedroom near Airport/Downtown and the Beach.', 2.0)
# ('Cosy room for one non-smoker', 0.6)
# ('Cosy top floor room.', 1.0)
# ('Cosy, Clean, Great location', 2.0)
# ('Cosy, Private Bedroom in Boston!', 2.06)
# ('Couch Crash in a Brewery Loft', 0.3)
# ('Cozy & Private Room close to city', 0.1)
# ('Cozy & Quiet Bedroom Near Subway', 3.33)
# ('Cozy + Central Back Bay Apartment', 0.23)
# ('Cozy 1 BR APT with assigned parking', 1.0)
# ("Cozy 1 Bd Artist's Sanctuary", 1.36)
# ('Cozy 1 Bed in Historic Charlestown', 1.53)
# ('Cozy 1 bedroom in stylish Cape', 5.25)
# ('Cozy 1-Bedroom in Fenway/Brookline', 0.7)
# ('Cozy 1-bed in Boston\'s "Southie"', 4.66)
# ('Cozy 1BD in Historic Beacon Hill', 1.08)
# ('Cozy 1BR w/ private deck in historic Charlestown!', 2.84)
# ('Cozy 2 bdr close to Harvard.', 1.22)
# ('Cozy 2BD North End apt', 4.29)
# ('Cozy 3 Bedroom, 1 Bath, 1st Floor', 6.67)
# ('Cozy Apartment + Porch in South End', 1.54)
# ('Cozy Apartment in a Great Location', 2.37)
# ('Cozy Apt @ Prime location. Steps to Bus & Trains!', 6.96)
# ('Cozy Apt in Symphony/Fenway', 1.26)
# ('Cozy Attic Bedroom in Allston', 0.17)
# ('Cozy Back Bay Penthouse!', 2.18)
# ('Cozy Back Bay Studio Apartment', 0.18)
# ('Cozy Bedroom in South Boston', 1.67)
# ('Cozy Boston apartment', 0.83)
# ('Cozy Boston bedroom with parking', 7.36)
# ('Cozy Brighton Apartment', 2.0)
# ('Cozy Chinatown/South End Studio', 1.91)
# ('Cozy Classic Boston Brownstone', 4.67)
# ('Cozy Condo w/ Separate Bath', 1.91)
# ('Cozy Double Times II', 2.59)
# ('Cozy Fenway Studio, Be Our Guest!', 2.66)
# ('Cozy Home in the Back Bay of Boston', 0.52)
# ('Cozy House in Quiet Neighborhood', 0.47)
# ('Cozy House on Bunker Hill in Boston', 0.92)
# ('Cozy JP Studio-Best Location!', 3.75)
# ('Cozy JP apt w/ short walk to T', 2.54)
# ('Cozy JP bedroom near Orange Line T', 1.35)
# ('Cozy JP resting place', 2.62)
# ('Cozy Luxury Apt in Boston/Backbay/Fenway/Symphony', 4.84)
# ('Cozy Nautical North End Apt', 2.07)
# ('Cozy North End Studio', 2.0)
# ('Cozy North End Studio - Perfect location!', 0.39)
# ('Cozy Private AC Bedroom in Boston', 6.1)
# ('Cozy Private Room Near Transit', 1.93)
# ('Cozy Private Room in Fenway/Kenmore', 0.38)
# ('Cozy Private Studio', 4.71)
# ('Cozy Reading Bedroom', 1.03)
# ('Cozy Remodeled Compact  Apartment', 2.81)
# ('Cozy Rm EZ St Parking EZ 2 downtown', 0.34)
# ('Cozy Room & Fresh Roasted Coffee', 1.16)
# ('Cozy Room + Private Bath, JP Boston', 0.31)
# ('Cozy Room Close to Everything!', 0.98)
# ('Cozy Room In JP', 1.65)
# ('Cozy Room for visiting Boston', 0.95)
# ('Cozy Room in Basement Near Subway', 3.09)
# ('Cozy Room in Brookline Apartment', 0.21)
# ('Cozy Room in Brownstone Building', 2.06)
# ('Cozy Room in Great Location Boston', 5.64)
# ('Cozy Room in Hip Local Neighborhood', 0.78)
# ('Cozy Room in Large Home!', 2.98)
# ('Cozy Room near Logan Airport ,T', 6.99)
# ('Cozy Room near the Heart of JP!', 1.44)
# ('Cozy Room off Centre St, JP!', 2.73)
# ('Cozy Room with AirBed', 0.69)
# ('Cozy Room with Shared Bath', 1.0)
# ('Cozy Room, Back Bay near Newbury St', 0.94)
# ('Cozy Room. Safe and Convenient Area', 0.28)
# ('Cozy South Boston Condo w/Backyard!', 1.89)
# ('Cozy South End Apt in best location', 1.06)
# ('Cozy South End Guest Room', 3.66)
# ('Cozy South End Studio For Two', 0.74)
# ('Cozy Studio ;-) in SOUTH END Boston', 1.44)
# ('Cozy Studio In Allston/Brookline', 1.0)
# ('Cozy Sunporch, Quick Downtown', 2.82)
# ('Cozy Sunroom in Secluded Townhouse', 0.74)
# ('Cozy Two bedroom apartment', 1.36)
# ('Cozy and Easy Access to Everything', 7.07)
# ('Cozy and Modern Bedroom #1: Subway/BU/BC/Harvard', 3.51)
# ('Cozy and Modern Bedroom #2: Subway/BU/BC/Harvard', 3.91)
# ('Cozy and Modern Bedroom #3: Subway/BU/BC/Harvard', 4.74)
# ('Cozy and Quaint home away from home', 1.76)
# ('Cozy and Quiet North End Duplex 1 Bedroom', 1.0)
# ('Cozy and convenient in Mission Hill', 0.63)
# ('Cozy apartment', 4.21)
# ('Cozy apartment in Boston', 2.0)
# ('Cozy apartment in Fenway', 0.41)
# ('Cozy apartment in great location', 1.79)
# ('Cozy apartment in heart of Back Bay', 1.42)
# ('Cozy apartment in ideal location', 3.12)
# ('Cozy apartment, awesome location', 0.32)
# ('Cozy artistic Room on Comm Ave', 0.23)
# ('Cozy bedroom', 0.08)
# ('Cozy bedroom near train, bus, parks', 0.41)
# ('Cozy bi-level Southie pad', 3.89)
# ('Cozy condo in South Boston', 0.31)
# ('Cozy den, private apt/kitchen/bath', 0.35)
# ('Cozy front room off the beaten path', 1.6)
# ('Cozy furnished 1 Bed, Longwood Med.', 2.33)
# ('Cozy guest room, great location!', 2.78)
# ('Cozy guest room. Awesome location!', 0.88)
# ('Cozy guest room. Awesome location!', 0.95)
# ('Cozy in Rozzie!', 0.37)
# ('Cozy luxury Apt near prudential Center', 4.69)
# ('Cozy modern BD w/ great city access', 0.17)
# ('Cozy modern room by the T', 0.32)
# ('Cozy modern room by the T', 0.41)
# ('Cozy one bedroom in Southie', 2.83)
# ('Cozy place in the North End', 0.11)
# ('Cozy place in the heart of Boston', 0.17)
# ('Cozy private room conveniently located', 8.49)
# ('Cozy private room in Charlestown', 0.39)
# ('Cozy private room near Fenway Park', 0.88)
# ('Cozy room #1 at nice apt. in Boston', 0.15)
# ('Cozy room #2 at nice apt. in Boston', 0.76)
# ('Cozy room #3 at nice apt. in Boston', 0.52)
# ('Cozy room around Longwood Medical Area', 3.0)
# ('Cozy room at Fenway', 6.23)
# ('Cozy room at a great location', 7.26)
# ('Cozy room at the heart of Boston', 8.33)
# ('Cozy room by the airport!', 0.99)
# ('Cozy room close to BU/Harvard', 0.47)
# ('Cozy room close to Downtown!', 0.39)
# ('Cozy room in Jamaica Plain', 0.4)
# ('Cozy room in a charming villa.', 1.24)
# ('Cozy room in a well located house', 0.36)
# ('Cozy room in apt close to T-stop!', 1.53)
# ('Cozy room in boston neighborhood', 0.44)
# ('Cozy room in central Boston', 2.5)
# ('Cozy room in front of metro station', 0.23)
# ('Cozy room in front of train/bus stp', 0.79)
# ('Cozy room in great location', 2.66)
# ("Cozy room in host's apt near train", 0.83)
# ('Cozy room near BU, BC', 0.3)
# ('Cozy room near LoganAirport & City!', 1.99)
# ('Cozy room near airport &  city', 1.59)
# ('Cozy room w/ pvt ba near Red Line!', 3.23)
# ('Cozy room(A) near T and downtown Boston', 3.5)
# ('Cozy room, 2 min walk to redline T', 0.63)
# ('Cozy rooms with parking and Wi-Fi', 4.1)
# ('Cozy studio close to Fenway park', 0.23)
# ('Cozy, 2 bedroom near medical area!', 0.12)
# ('Cozy, Convenient Back Bay Home', 1.96)
# ('Cozy, One bedroom Condo, Back Bay', 1.56)
# ('Cozy, Patio, Pool, and Whole Foods', 3.12)
# ('Cozy, Private Room', 0.78)
# ('Cozy, bohemian Jamaica Plain studio', 4.14)
# ('Cozy, colorful & private on a park', 2.55)
# ('Cozy, convenient Fenway 1 BR', 1.58)
# ('Cozy, high-rise room, stunning view', 10.28)
# ('Cozy, quiet room in Roslindale', 5.77)
# ('Cozy, room located near bus (to train station)', 4.62)
# ('Cozy/Stylish btwn Dwntwn & Airport', 2.06)
# ('Crash in a lux high rise for cheap', 2.07)
# ('Crisp Linen Living near Harvard Square', 1.08)
# ('Cute & Comfy in JP!', 0.48)
# ('Cute 1 bed in the heart of Boston.', 1.19)
# ('Cute Apt Steps to T & Prudential Shops/Newbury St', 5.42)
# ('Cute and cozy apt right on Newbury!', 1.0)
# ('Cute bedroom in the Allston area', 0.07)
# ('Cute studio in Boston Backbay!', 0.05)
# ('Cute&cosy bedroom-close to bus & T', 0.09)
# ('DOWNTOWN BOSTON 2BR APT-OPERA HOUSE', 0.6)
# ('DOWNTOWN MODERN 2 BED', 3.84)
# ('Deck right on East Broadway!', 0.55)
# ...
# ('Sunny South Boston apartment', 0.08)
# ('Sunny South End Brownstone', 7.16)
# ('Sunny South End Brownstone w/ Deck', 1.52)
# ('Sunny Spacious Brookline Apartment', 5.33)
# ('Sunny Studio', 0.26)
# ('Sunny Studio at Fenway', 4.93)
# ('Sunny Studio in Back Bay/ S. End', 1.14)
# ('Sunny Studio in Heart of South End', 1.68)
# ('Sunny Top Floor Apartment', 0.66)
# ('Sunny Two Bedroom Condo', 0.48)
# ('Sunny and Quiet top floor #8', 1.73)
# ('Sunny and Spacious in the heart of Hyde Square', 0.43)
# ('Sunny and quiet private room close to subway (JP)', 3.91)
# ('Sunny apartment in Back Bay', 0.81)
# ('Sunny apartment in Boston hosts 6', 1.53)
# ('Sunny bedroom in Allston', 0.8)
# ('Sunny bedroom in large quiet house', 1.67)
# ('Sunny bedroom with private bathroom', 4.02)
# ('Sunny house in historic district', 5.2)
# ('Sunny musicians apt. close to T!', 3.75)
# ('Sunny private room with comfy bed', 0.64)
# ('Sunny renovated 1 bed, near BC,BU', 2.12)
# ('Sunny renovated 1 bedroom in friendly East Boston', 2.67)
# ('Sunny room 15 min from downtown!', 7.07)
# ('Sunny room in Boston (JP)', 0.99)
# ('Sunny room in great Boston location', 0.42)
# ('Sunny room with a harbor view!', 2.37)
# ('Sunny studio in Back Bay/So. End', 3.08)
# ('Sunny studio in a great location.', 0.39)
# ('Sunny, Cozy and Convenient JP Home!', 1.08)
# ('Sunny, Family-Friendly Apartment', 0.22)
# ('Sunny, Safe, Spacious Room Near T!', 4.87)
# ('Sunny, Spacious and Affordable ', 0.13)
# ('Sunny, Top Floor 2BR with Views', 1.66)
# ('Sunny, art-filled North End loft with fireplace', 1.12)
# ('Sunny, large private room in an AMAZING location', 0.53)
# ('Sunny, private with bath near train', 2.0)
# ('Sunset Room near Harvard Square (BR 2)', 2.72)
# ("Super Cozy Apt - An Artist's Home", 1.06)
# ('Super Studio-Private and Convenient', 3.86)
# ('Super cool! Modern  2 bedroom loft ', 1.33)
# ('Super quiet, minutes from Downtown!', 3.91)
# ('Superb 1BR Back Bay Condo', 1.48)
# ('Surround yourself with custom art!', 1.06)
# ('Swanky Studio in Historic Back Bay', 2.04)
# ('Sweet Little House in JP, Boston', 3.86)
# ('Sweet South End Digs', 0.6)
# ('Sweet Spot, Fort hill', 0.44)
# ('Sweet penthouse in historic Boston', 0.62)
# ('Sweet quiet room in JP condo', 1.14)
# ('Sweetest place ever ❤️', 1.03)
# ("T'BEST: Priv. Bath, Deck; Subway, Parking Option", 3.0)
# ('TRUE South End PERFECT!!!!', 1.99)
# ('TWO BEDROOM APARTMENT', 5.61)
# ('Take me to Fenway! Boston studio', 7.53)
# ('Temple Street By Maverick, Eight', 0.5)
# ('Temple Street By Maverick, Eleven', 0.34)
# ('Temple Street By Maverick, Fifteen', 0.48)
# ('Temple Street By Maverick, Nine', 0.49)
# ('Temple Street By Maverick, One', 0.63)
# ('Temple Street By Maverick, Seven', 0.63)
# ('Temple Street By Maverick, Six', 0.09)
# ('Temple Street By Maverick, Ten', 0.2)
# ('Temple Street By Maverick, Thirteen', 0.19)
# ('Temple Street By Maverick, Three', 0.16)
# ('Temple Street By Maverick, Twelve', 0.19)
# ('Temple Street By Maverick, Two', 2.0)
# ('Temporary Housing - Boston', 3.75)
# ('Temporary Housing Boston', 3.44)
# ('Terrestrial Paradise of Eternal Love', 0.86)
# ('The Artist room in beautiful villa.', 0.33)
# ('The Best Location In Boston', 3.69)
# ('The Blue Room in JP', 0.78)
# ('The Cape Cod Room near Harvard Square', 1.46)
# ('The City Cabin - 2 blocks to Subway', 6.36)
# ('The Dorset | 3BR 1BA | 1st Floor', 0.22)
# ('The Golden Slipper', 0.52)
# ('The Grand View | 4 BR 2BA | Home', 0.41)
# ('The Heart of Cleveland Circle', 1.31)
# ('The Hedges: Sunny urban garden home', 2.62)
# ("The King's Palace ", 0.04)
# ('The Little Room', 1.01)
# ('The Mandarin near Harvard Square', 1.66)
# ('The Mayhew | 2BR 1BA | 3rd Floor', 0.2)
# ('The Meditation Room near Harvard Square', 2.78)
# ('The Misty Morning near Harvard Square (Bedroom F)', 0.36)
# ('The Music Box', 2.06)
# ('The Penthouse | 2BR 1BA | 4th Floor', 0.41)
# ('The Presidential with Private Bath', 1.3)
# ('The Rainbow Room', 2.0)
# ('The Red Brick Road', 1.0)
# ('The Rolls Royce Room near Harvard Square', 1.38)
# ('The Roost -  Fox Room', 3.27)
# ('The Roost- The Elephant Room', 3.93)
# ('The Roost-Master Suite-The Lion', 3.25)
# ('The Roseclair | 3BR 1BA | 2nd Floor', 0.52)
# ('The Sail Loft near Harvard Square', 0.66)
# ('The Sawyer | 2BR 2.5BA | 1st Floor', 0.16)
# ('The Shawmut | 2BR 1BA | 1st Floor', 0.22)
# ('The Sky View | 2BR 1BA | 3rd Floor', 0.08)
# ('The Sunrise Room near Harvard Square (Bedroom G)', 0.72)
# ('The Tiffany Room near Harvard Square', 1.57)
# ('The Treehouse', 0.6)
# ('The Treehouse', 1.53)
# ('The Urban Treehouse', 1.38)
# ('The apartment you were looking for!', 1.0)
# ('The apartment you were looking for!', 2.0)
# ('The heart of Downtown', 5.34)
# ('The place to be. Believe me and bnb', 0.27)
# ('TheDartmouthExecutiveSuite.com', 0.07)
# ('Theater District 1BR 1Bath Cityview', 0.44)
# ('Theater District 2 LEVEL LOFT!', 4.22)
# ("There's No Place Like {Our} Home", 0.62)
# ('Three blocks from marathon finish', 0.12)
# ('Top floor Brownstone, tree-lined st', 0.23)
# ('Top floor condo w/ parking, roof deck, near beach', 3.16)
# ('Top floor cozy apartment', 2.31)
# ('Top of the South End Brownstone', 0.77)
# ('Totally Amazing XL Studio w Skyline', 0.27)
# ('Tourist Best Choice Master Bedroom Subway/Downtown', 2.44)
# ('Tourist Best Choice Penhouse Subway/Downtown', 1.91)
# ('Tourist Best Choice Private Room Subway/Downtown', 2.79)
# ('Townhouse next to the Boston Common', 0.64)
# ('Tranquil Treetop Loft', 8.67)
# ('Transit Accessible Private Room With Airbed!', 1.0)
# ('Treetop 2+BR Condo w/ Guest Hammock', 0.56)
# ('Treetop Haven in the City', 1.9)
# ('Treetop Haven-Eclectic Boston Area', 0.5)
# ('Treetop Jamaica Plain home', 0.49)
# ('Treetop Room in Sunny Pondside Home', 0.5)
# ('Trendy JP Condo, Steps from T', 0.15)
# ('Trendy Loft in the South End', 1.21)
# ('Twins in a peaceful room.', 1.25)
# ('Two Bedroom Kenmore Square', 3.93)
# ('Two Bedroom apartment, East Boston', 7.34)
# ('Two Room Master Suite with Spa Bath', 4.57)
# ('Two rooms and a small entryway', 0.25)
# ('Two rooms in Arts & Crafts Bungalow', 2.11)
# ('Ultimate Convenience!', 2.0)
# ('Umass, City, MGH, BCEC, Longwood 2E', 0.13)
# ('Umass, City, MGH, Longwood, BWH (A)', 0.68)
# ('Umass, City, MGH,BECE,Longwood 3A', 0.95)
# ('Umass, Harvard, MGH,Longwood, 16D', 0.12)
# ('Umass, MGH, City, BCEC, Longwood3E', 0.22)
# ('Umass, MGH, City,BCEC,Longwood 2B', 0.33)
# ('Umass, MGH, City,BCEC,Longwood 3B', 0.22)
# ('Umass, city,MGH,BCEC,Longwood 16E', 0.09)
# ('Umass,City, BECE, MGH, Longwood 16s', 0.42)
# ('Umass,City,MGH,Longwood(BI,BWH)(D)', 0.6)
# ('Umass,MGH,City,BCEC, Longwood(E)', 0.36)
# ('Umass,MGH,City,BCEC,Longwood 2A', 0.08)
# ('Umass,MGH,Harvard,MIT,Longwood A3', 0.21)
# ('Umass,city, longwood, MGH, BCEC 16B', 0.15)
# ('Uncommon Place (free parking!)', 1.89)
# ('Under the Light of Old North Church', 6.13)
# ('Unique 3 Bed, 2 Bath Apartment ', 3.9)
# ('Unique Fenway/Back Bay/Copley 1 Bed', 3.0)
# ('Unique Find: Private home in City!', 1.17)
# ('Unique Loft in Central JP Location', 0.82)
# ('Unique Penthouse in Central Boston', 0.18)
# ('Unique cozy apartment in Back Bay - Boston', 0.56)
# ('Updated Condo in South Boston', 3.26)
# ('Updated South Boston Condo', 0.42)
# ('Updated South End/Back Bay 1-Bed', 0.52)
# ('Updated large bedroom, with couch and central air', 2.43)
# ('Updated, spacious living in Rozzie', 0.64)
# ('Upscale 1 bedroom Apartment', 3.13)
# ('Upscale 1BR w/ Skyline Views', 0.09)
# ('Upscale Back Bay Studio, River Views', 1.66)
# ('Upscale Faneuil Hall / N. End Oasis', 6.9)
# ('Urban 1850s farmhouse', 4.27)
# ('Urban Victorian-walk the city! Rm 2', 0.74)
# ('Urban Victorian-walk the city! Rm 3', 1.02)
# ("Urban oasis trendy JP 'hood - suite", 2.63)
# ('Urban oasis, wonderful location!', 9.55)
# ('VERY SMALL STUDIO FOR ONE', 2.74)
# ('VERY convenient COUCH in a LUXURIOUS house near BU', 0.37)
# ('Vacation, Business, Location!', 2.13)
# ("Verona's Victorian Charm (# 6) M314 SPECIAL $155", 0.7)
# ('Very Central, Safe and Quiet', 0.93)
# ('Very Close 2 Red Line with AirBed!', 0.25)
# ('Very Rare Luxury New Three Bedroom', 3.98)
# ('Very good location', 0.12)
# ('Very spacious Back Bay, 1 block T', 2.69)
# ('Vibrant East Boston Apartment', 0.18)
# ('Victorian Charm, Modern Living: South End/Back Bay', 1.0)
# ('Victorian Dream Studio, South End', 0.52)
# ('Victorian Full Bed', 2.53)
# ('Victorian Garden Level Room - Omega', 2.0)
# ('Victorian In-law', 1.71)
# ('Victorian Tranquility Next to the T', 8.86)
# ('Victorian charm in the city', 1.38)
# ('Victorian house One bedroom apt furnished', 1.3)
# ('Victorian queen', 2.79)
# ('Views, Amenities, Location, Bingo!', 1.01)
# ('Vintage Apt With 3 Large Bedrooms', 0.33)
# ('Visit Boston 30 min from Downtown', 0.97)
# ('Visit Boston 30 min from Downtown#2', 1.61)
# ('Walk Downtown! Freedom Trail Studio', 1.28)
# ('Walk To The Beach or City', 9.45)
# ('Walk To The Beach or City 2', 8.06)
# ('Walk to Medical', 2.84)
# ('Walk to Medical, Queen', 2.35)
# ('Walk to T,Beach,Gd eats, 5 rooms', 1.34)
# ('Warm 1 Bedroom Near Airport', 0.13)
# ('Warm Huge Room (*Girl Only)', 0.44)
# ('Warm and Cozy II ', 0.91)
# ('Warm and Cozy, Room B', 2.98)
# ('Warm spacious, clean room.  You will Restmore', 2.0)
# ('Waterfall Room: Bunker Hill B&B', 0.35)
# ('Welcome Home', 5.45)
# ('Welcome Home! 3bed near T w parking', 0.89)
# ('Welcome to Shangri la', 3.74)
# ('Welcome to cozy groundfloor 2rm apt', 6.15)
# ('Welcome to my beautiful home.', 2.6)
# ('Welcome2Boston2: Near BC/BU/Harvard', 2.46)
# ('Well lit condo in BeaconHill Boston', 0.07)
# ('West Boston BU, 2 BR 3 Bed Apt.', 2.06)
# ('West Broadway Quarters - hostel style unit', 0.27)
# ('West Broadway Quarters - hostel style unit', 1.22)
# ('West Broadway Quarters - hostel unit', 0.37)
# ('West Broadway Quarters - hostel unit', 0.53)
# ('West Canton By Maverick', 0.33)
# ('West End 12th Floor: by Spare Suite', 0.64)
# ('West End 30th Floor: by Spare Suite', 0.19)
# ('West End ❤️ of Boston', 1.0)
# ('West Roxbury (Boston) private room', 1.46)
# ('White Elephant Inn - Downtown! ', 0.2)
# ('Whole Apt.2 beds,wifi,close train', 1.28)
# ('Whole one-bedroom apartment', 0.05)
# ('Wonderful Boston apartment- 8 people', 2.83)
# ('Wonderful home Great Neighborhood mins from Boston', 0.13)
# ('Wonderful room in back bay', 0.43)
# ('Yacht Rental Lola Downtown Boston! ', 0.29)
# ('Yknot - Fabulous Rental on Water!', 0.07)
# ('Your Home Away from Home', 0.59)
# ('Your Huge Beautiful Home away from Home', 0.04)
# ('Your own bedroom, sitting room and bathroom near T', 2.09)
# ('Your urban oasis', 5.0)
# ('Zephyr Yacht - Heated and Insulated', 0.82)
# ('[1125-1]Furnished 1BR - Landmark Square', 0.04)
# ('[1125]Furnished 1BR', 0.07)
# ('[1168-1C]Elegant 1BR - Downtown Boston', 0.09)
# ('[1168-1NE]Beautiful 1BRs - Washington Street', 0.09)
# ('[1168-2C]Elegant 2BRs - Downtown Boston', 0.17)
# ('[1168-2NH]Lux 2BR - Downtown Boston', 0.32)
# ('[1218-2NH]2BR Apartment in Boston', 0.08)
# ('[1246-1C]Beautiful 1BRs - Fenway Area', 0.01)
# ('[1246-1NE]Luxury 1BR - Fenway Area', 0.08)
# ('[1246-2C]Elegant 2BRs - Fenway Area', 0.03)
# ('[1246-2C]Lux 2BR - Fenway Area', 0.08)
# ('[1246]Beautiful 2BRs - Fenway Area', 0.12)
# ('[1247-2C]Furnished 2BR At The Vesta', 1.46)
# ('[1247-2NH]Furnished 2BR At The Vesta', 0.09)
# ('[1250-1P] 1BR Furnished in Back Bay', 0.07)
# ('[1250-2/1] 2BR Lux Back Bay Rental.', 0.22)
# ('[1250-2C] Beautiful 2BRs in Back Bay Near The Pru', 0.03)
# ('[1250-2C]Elegant 2BRs in Back Bay', 0.13)
# ('[1250-2NE] 2BR Lux Back Bay Rental', 0.15)
# ('[1250-2NE] 2BR-1 Bath - Back Bay', 0.17)
# ('[1250]Beautiful 2BRs in Back Bay', 0.17)
# ('[1273-1]Fab Studio Close to Newbury', 0.17)
# ('[1273-S]Fab Studio close to Newbury', 0.42)
# ('[1273] Fab Studio- close to Newbury', 0.35)
# ('[1274]1BR Half Block from Newbury', 0.08)
# ('[1275]2BR-Off Newbury St.- Back Bay', 0.34)
# ('[1277/1] 1BR on Beacon St- Back Bay', 0.36)
# ('[1277] 1BR on Beacon St - Back Bay', 0.28)
# ('[1279/1] 2 BR 1.5BA, Bi-Level Suite', 0.12)
# ('[1279] 2 BR/1.5 BA, Bi-Level Suite', 0.21)
# ('[1280-2]Lux 2BR In Back Bay', 0.25)
# ('[1280] Luxury 2BR Suite-Back Bay', 0.35)
# ('[1293-1/1] Lovely 1 BR in South End', 0.11)
# ('[1293-1] - 1 Bedroom in South End', 0.12)
# ('[1293] Lovely 1 BR in South End', 0.06)
# ('[1294-S]Grand Studio - South End', 0.03)
# ('[1294] Grand Studio - South End', 0.15)
# ('[1300] 3 Bedroom-Back Bay-Penthouse', 0.38)
# ('[1330-1C] Lux High Rise in Fenway', 0.02)
# ('[1330-1D] Lux 1BR  w/ Den - Fenway', 0.04)
# ('[1330-2] Lux 2BR in The Fenway', 0.09)
# ('[1344] 1 BR Penthouse w/ Roof Deck', 0.39)
# ('[1356-2] 2BR Exec Penthouse Suite', 0.07)
# ('[1358-S]Small Studio In South End', 0.03)
# ('[1358] Small Studio in South End', 0.05)
# ('[1414] Renovated Beacon Hill Studio', 0.19)
# ('[1426-2]NEW 3 BR-Bi-Level  Back Bay', 0.6)
# ('[1426] NEW 3 BR, Bi-Level-Back Bay', 0.67)
# ('[1535-1C] 1BR - West End High Rise', 0.06)
# ('[1535-1N] 1BR - West End High Rise', 0.06)
# ('[1535-2C]2BR - West End High Rise', 0.17)
# ('[1684-2]2BRs-Near Longwood Med Area', 0.05)
# ('[1684-ST] Lux 1BR-Longwood Med Area', 0.02)
# ('[1689] Brand New 2BR off Newbury St', 0.36)
# ('[1716-1/2]Brand New 1BR in Back Bay', 0.33)
# ('[1716-1] Brand New 1BR - Back Bay', 0.44)
# ('[1716-2] Brand New 2BR -Back Bay', 0.49)
# ('[1798]2BR at Emerson Place, Boston', 0.05)
# ('[1852-2C]2BRs in Downtown Boston', 0.17)
# ('[1852-N]Lux 2BR - Downtown Boston', 0.25)
# ('[1852-ST] Lux 2BR-Downtown Boston', 0.11)
# ('[1857]2BR At Radian Apartments', 0.04)
# ('[1909-1N]1BR -The Victor-North End', 0.13)
# ('[1909-2N]2BR -The Victor-North End', 0.09)
# ('[1909-2] 2BR -The Victor-North End', 0.16)
# ('[2002]1BR - Waterside Place', 0.43)
# ('^Tourist Best Choice Master Bdrm Subway/Downtown', 4.8)
# ('^Tourist Best Choice Private Room Subway/Downtown', 1.81)
# ('`Hidden Gem in Boston', 4.43)
# ('a Cozy Sunroom in Allston', 4.57)
# ('a*SUNNY BRIGHT & COZY ROOM BOSTON*', 1.69)
# ('b **SPACIOUS & SUNNY ROOM BOSTON**', 2.38)
# ('b Pleasant & Peaceful near T & Bus', 1.88)
# ('beautiful seaport Apartment', 1.64)
# ('beautifully renovated 1st floor apt', 1.0)
# ('bedroom in North End', 2.6)
# ('best location best price绝佳地段价格优惠', 2.26)
# ('best place to live', 0.08)
# ('big bright room in 4b1b near T/longwood', 0.94)
# ('bright 3floor bedroom in a old brick city house', 1.0)
# ('bright room in 4b1b near T/longwood, 1b/room', 1.3)
# ('c Secluded & Serene Allst/Brigh', 2.8)
# ('clean room steps to subway&airport', 0.47)
# ('cosy-sunny 2-BR apt. close to subway,beach,highway', 1.71)
# ('cozy sunny studio ( St Elizabeth H)', 2.08)
# ('d ** BEST PRIVATE ROOM IN BOSTON **', 3.09)
# ('d Quiet, Close to T Allston/Bright', 1.69)
# ("e **BRIGHT 'N CHEERY QUIET ROOM**", 2.21)
# ('e Sunny & Spacious AllstonBrighton', 2.19)
# ('extra 25% OFF!! FUN studio, Fast WiFi', 4.02)
# ('f STUNNING ROOM w/PRIVATE 1/2 BATH', 1.77)
# ('friendly family home', 5.51)
# ('furnished 1 bed apartment copley #5', 1.12)
# ('g Private entrance room Allston ', 1.6)
# ('great view', 1.0)
# ('h Spacious room Allston/Brighton ', 2.9)
# ('i Massive Sunny Room Allston/BostoN', 3.28)
# ('j Allston green rm w/ private exit ', 3.43)
# ('k Best Room Boston', 3.91)
# ('king size bed,clear and neat,wifi, 2min to train', 0.75)
# ('l GREAT ROOM BOSOTN', 3.16)
# ('large & grand 2 bedroom South End by Copley Sq #3', 2.36)
# ('lovely family', 3.7)
# ('lovely sunny room in Boston', 1.23)
# ('lovely upscale townhouse apartment', 0.56)
# ('near BC shuttle house summer sublet', 0.65)
# ('near Harvard business School', 0.86)
# ('new two bed room Apartment the end day is 7/31/16.', 2.78)
# ('newly furn one bedroom by Copley #6', 1.88)
# ('north slope studio in boston proper', 7.7)
# ('private BR in North end, Boston', 3.96)
# ('room in 4bed 2bath near T/NEU/Longwood/BU Medical', 1.5)
# ('room in beautiful house', 0.88)
# ('south end/back bay brownstone', 1.6)
# ('spacious 3rd floor loft in home', 2.54)
# ('spacious room near subway&airport', 0.37)
# ('start here&walk all around boston', 8.01)
# ('sunny and warm bedroom, 1min to T.', 7.16)
# ('sunny furnished studio close to T', 0.35)
# ('sunny,cozy,near BC,BU,Boston,MBTA', 2.88)
# ('the apartment in the sky', 1.92)
# ('warm and Cozy', 3.17)
# ('wifi,clean,neat,A/C,locker,1 min to train,washer', 3.66)
# ('zWestPrivateBedBath MinsToBus,Metro', 1.37)
# ('zzEastPrivateBedBath MinsToBus,Metro,HistoricSites', 2.41)
# ('zzzParking? MASTER CALENDAR   OnlyEd Books forYou', 0.65)
# ('❤️ of Boston, South End, Back Bay', 0.25)
# ('【Boston】中心近【Chinatown】', 1.0)
# ('交通便利 经济实惠的公寓单间。', 0.75)
# ('位于比肯山的1卧單位房源', 1.29)
# ('温馨双人房，一分钟到地铁。', 7.67)
# ('红线地铁JFK/UMASS 站边上的一个房间', 5.12)
